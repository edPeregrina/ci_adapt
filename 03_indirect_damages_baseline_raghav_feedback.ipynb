# %% [markdown]
# WIP, currently only flow model

# %%
#ADDITIONAL DEPENDENCIES
# !pip install triangle
# !pip install rasterio
# !pip install geopy
# !pip install osmnx
# Out:
# Collecting triangle
#   Downloading triangle-20230923-cp312-cp312-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from triangle) (1.26.4)
# Downloading triangle-20230923-cp312-cp312-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.4 MB 108.9 kB/s eta 0:00:13
#     --------------------------------------- 0.0/1.4 MB 108.9 kB/s eta 0:00:13
#     --------------------------------------- 0.0/1.4 MB 108.9 kB/s eta 0:00:13
#     --------------------------------------- 0.0/1.4 MB 108.9 kB/s eta 0:00:13
#    - -------------------------------------- 0.0/1.4 MB 115.5 kB/s eta 0:00:12
#    ----------------------------- ---------- 1.0/1.4 MB 3.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.0/1.4 MB 3.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.0/1.4 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.4 MB/s eta 0:00:00
# Installing collected packages: triangle
# Successfully installed triangle-20230923
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from rasterio) (23.1.0)
# Requirement already satisfied: certifi in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from rasterio) (2024.6.2)
# Requirement already satisfied: click>=4.0 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from rasterio) (1.26.4)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: click-plugins in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from rasterio) (68.2.2)
# Requirement already satisfied: colorama in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: pyparsing>=2.1.6 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Downloading rasterio-1.3.10-cp312-cp312-win_amd64.whl (24.3 MB)
#    ---------------------------------------- 0.0/24.3 MB ? eta -:--:--
#    ---------------------------------------- 0.2/24.3 MB 5.6 MB/s eta 0:00:05
#    ------ --------------------------------- 4.0/24.3 MB 64.9 MB/s eta 0:00:01
#    ------------- -------------------------- 8.3/24.3 MB 76.3 MB/s eta 0:00:01
#    --------------------- ------------------ 12.8/24.3 MB 110.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 17.2/24.3 MB 131.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.8/24.3 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  24.3/24.3 MB 131.2 MB/s eta 0:00:01
#    ---------------------------------------  24.3/24.3 MB 131.2 MB/s eta 0:00:01
#    ---------------------------------------  24.3/24.3 MB 131.2 MB/s eta 0:00:01
#    ---------------------------------------- 24.3/24.3 MB 59.4 MB/s eta 0:00:00
# Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    ------ -------------------------------- 20.5/125.4 kB 217.9 kB/s eta 0:00:01
#    --------- ----------------------------- 30.7/125.4 kB 262.6 kB/s eta 0:00:01
#    --------- ----------------------------- 30.7/125.4 kB 262.6 kB/s eta 0:00:01
#    -------------------------------------- 125.4/125.4 kB 738.4 kB/s eta 0:00:00
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#    ------------------------------ --------- 30.7/40.3 kB ? eta -:--:--
#    ------------------------------ --------- 30.7/40.3 kB ? eta -:--:--
#    ------------------------------ --------- 30.7/40.3 kB ? eta -:--:--
#    ---------------------------------------- 40.3/40.3 kB 276.0 kB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# Collecting osmnx
#   Downloading osmnx-1.9.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: geopandas>=0.12 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from osmnx) (0.14.2)
# Requirement already satisfied: networkx>=2.5 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from osmnx) (3.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from osmnx) (1.26.4)
# Requirement already satisfied: pandas>=1.1 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from osmnx) (2.2.1)
# Requirement already satisfied: requests>=2.27 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from osmnx) (2.31.0)
# Requirement already satisfied: shapely>=2.0 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from osmnx) (2.0.1)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from geopandas>=0.12->osmnx) (1.9.5)
# Requirement already satisfied: packaging in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from geopandas>=0.12->osmnx) (23.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from geopandas>=0.12->osmnx) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from pandas>=1.1->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from pandas>=1.1->osmnx) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from pandas>=1.1->osmnx) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from requests>=2.27->osmnx) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from requests>=2.27->osmnx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from requests>=2.27->osmnx) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from requests>=2.27->osmnx) (2024.6.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from fiona>=1.8.21->geopandas>=0.12->osmnx) (23.1.0)
# Requirement already satisfied: click~=8.0 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from fiona>=1.8.21->geopandas>=0.12->osmnx) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from fiona>=1.8.21->geopandas>=0.12->osmnx) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from fiona>=1.8.21->geopandas>=0.12->osmnx) (0.7.2)
# Requirement already satisfied: six in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from fiona>=1.8.21->geopandas>=0.12->osmnx) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from fiona>=1.8.21->geopandas>=0.12->osmnx) (68.2.2)
# Requirement already satisfied: colorama in c:\users\peregrin\appdata\local\anaconda3\envs\ci_adapt_env\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas>=0.12->osmnx) (0.4.6)
# Downloading osmnx-1.9.3-py3-none-any.whl (107 kB)
#    ---------------------------------------- 0.0/107.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/107.2 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/107.2 kB ? eta -:--:--
#    ------- ------------------------------- 20.5/107.2 kB 222.6 kB/s eta 0:00:01
#    ----------- --------------------------- 30.7/107.2 kB 187.9 kB/s eta 0:00:01
#    -------------------------------------- 107.2/107.2 kB 775.4 kB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-1.9.3

# %%
import sys
import os
sys.path.append(r'C:\repos\snkit\src')
sys.path.append(r'C:\repos')
sys.path.append(r'C:\repos\ra2ce')
sys.path.append(r'C:\repos\ra2ce_multi_network')
from ci_adapt_utilities import *
from ci_adapt_classes import *
from ra2ce_multi_network.simplify_rail import *
from ra2ce_multi_network.simplify_rail import _merge_edges, _network_to_nx
import networkx as nx
import pandas as pd
from shapely import wkt, box, is_valid, make_valid
import re
from math import ceil

# %%
# Load configuration with ini file (created running config.py)
config_file=r'C:\repos\ci_adapt\config_ci_adapt.ini'
config = configparser.ConfigParser()
config.read(config_file)

# Set paths and data sources
p = Path('..')
hazard_type = config.get('DEFAULT', 'hazard_type')
infra_type = config.get('DEFAULT', 'infra_type')
country_code = config.get('DEFAULT', 'country_code')
country_name = config.get('DEFAULT', 'country_name')
hazard_data_subfolders = config.get('DEFAULT', 'hazard_data_subfolders')
asset_data = config.get('DEFAULT', 'asset_data')
vulnerability_data = config.get('DEFAULT', 'vulnerability_data')
data_path = Path(pathlib.Path.home().parts[0]) / 'Data'
interim_data_path = data_path / 'interim' / 'event_data_inspection'/ 'overlapping_floods_shapefiles'

# %%
#FUNCTION DEFINITIONS
# Create a bounding box around the graph
def get_bbox(graph):
    min_x = min([attr['pos'][0] for _, attr in graph.nodes(data=True)])
    max_x = max([attr['pos'][0] for _, attr in graph.nodes(data=True)])
    min_y = min([attr['pos'][1] for _, attr in graph.nodes(data=True)])
    max_y = max([attr['pos'][1] for _, attr in graph.nodes(data=True)])
    
    return min_x, max_x, min_y, max_y

# Assign a weight to each edge based on the length of the edge
def set_edge_weights(assets, graph):
    # Create a dictionary to store the length of each asset
    asset_lengths = {str(asset['osm_id']): asset['geometry'].length for asset_id, asset in assets.iterrows()}

    # Loop through the edges and assign the length of the asset to the edge
    for u, v, attr in graph.edges(data=True):
        if 'source_sink' in str(u) or 'source_sink' in str(v):
            continue

        # Initialize the weight and length of the edge
        attr['weight'] = int(0)
        attr['length'] = 0
        if 'osm_id' not in attr:
            continue
        
        # For concatenated edges, split the osm_id string and sum the lengths for each asset
        osm_ids = attr['osm_id'].split('; ')
        for osm_id in osm_ids:
            if osm_id in asset_lengths:
                attr['length'] += asset_lengths[osm_id]
                attr['weight'] += int(round(asset_lengths[osm_id]*1e3,0))

    return graph

def _create_terminal_graph(graph):
    # Make a copy of the graph with only the nodes identified as possible terminals
    terminal_graph = graph.copy()
    for u, attr in graph.nodes(data=True):
        if 'possible_terminal' not in graph.nodes[u]:
            continue
        if attr['possible_terminal'] == 0: 
            terminal_graph.remove_node(u)
    return terminal_graph

def shortest_paths_between_terminals(graph, route_data):
    # Make a copy of the graph with only the nodes identified as possible terminals
    terminal_graph = _create_terminal_graph(graph)

    # Create a dictionary to store the shortest path between each OD pair
    paths={}

    # Iterate over all route ODs pairs and find the shortest path between the two nodes
    for _, attr in route_data.iterrows():

        # Snap route origin and destination geometries to nearest terminal node on graph
        if wkt.loads(attr['geometry_from']).geom_type == 'Point':
            centroid_from = wkt.loads(attr['geometry_from'])
        else:
            centroid_from = wkt.loads(attr['geometry_from']).centroid
        from_nearest_node = nearest_nodes(terminal_graph, centroid_from, 1)
        if wkt.loads(attr['geometry_to']).geom_type == 'Point':
            centroid_to = wkt.loads(attr['geometry_to'])
        else:
            centroid_to = wkt.loads(attr['geometry_to']).centroid
        to_nearest_node = nearest_nodes(terminal_graph, centroid_to, 1)

        # If the nearest nodes are the same for the origin and destination, skip the route
        if from_nearest_node[0][0] == to_nearest_node[0][0]:
            continue

        # Find the shortest path between the two terminals and the average flow on the path
        try:
            shortest_path = nx.shortest_path(graph, from_nearest_node[0][0], to_nearest_node[0][0], weight='weight')
            paths[(from_nearest_node[0][0], to_nearest_node[0][0])] = (shortest_path, int(ceil(attr['goods']/52)))
                
        except nx.NetworkXNoPath:
            print(f'No path between {from_nearest_node[0][0]} and {to_nearest_node[0][0]}')
            continue               

    return paths

def set_edge_capacities(graph, route_data, simplified=False):
    

    # Find shortest paths between each OD pair
    paths=shortest_paths_between_terminals(graph, route_data)
    
    if simplified==True:
        for _,_, attr in graph.edges(data=True):
            if 'capacity' not in attr:
                attr['capacity'] = 1
        
        return graph, paths

    # Assign capacity to edges that are part of a shortest path
    for (_,_), (nodes_in_path,average_flow) in paths.items():
        for i in range(len(nodes_in_path)-1):
            if not graph.has_edge(nodes_in_path[i], nodes_in_path[i+1], 0):
                continue
            if nodes_in_path[i]=='source_sink' or nodes_in_path[i+1]=='source_sink':
                continue 
            if 'capacity' in graph[nodes_in_path[i]][nodes_in_path[i+1]][0]:
                graph[nodes_in_path[i]][nodes_in_path[i+1]][0]['capacity'] = max(graph[nodes_in_path[i]][nodes_in_path[i+1]][0]['capacity'],2*average_flow)
            else:
                graph[nodes_in_path[i]][nodes_in_path[i+1]][0]['capacity'] = 2*average_flow
    
    # Set the capacity of edges that are not on a shortest path to the median capacity
    caps=[attr['capacity'] for _, _, attr in graph.edges(data=True) if 'capacity' in attr]
    
    median_cap = int(np.median(caps))

    for _,_, attr in graph.edges(data=True):
        if 'capacity' not in attr:
            attr['capacity'] = median_cap
        
    return graph, paths

# Function to find the nearest node in a graph to a point
def nearest_nodes(graph, point, n):
    nearest_nodes = []
    for node, attr in graph.nodes(data=True):
        if 'geometry' in attr:
            distance = point.distance(attr['geometry'])
            nearest_nodes.append((node, distance))
    nearest_nodes = sorted(nearest_nodes, key=lambda x: x[1])

    return nearest_nodes[:n]

# Function to set the demand of each node based on the OD data
def set_node_demand(od_data, graph):
    # make a copy of the graph with only the nodes where possible_terminal is 1
    terminal_graph = graph.copy()
    for u, attr in graph.nodes(data=True):
        if attr['possible_terminal'] == 0: 
            terminal_graph.remove_node(u)

    # Loop through od_data and assign demand to the nearest terminal node
    for od in od_data.iterrows():
        if od[1]['geometry'].geom_type == 'Point':
            centroid = od[1]['geometry']
        else:
            centroid = od[1]['geometry'].centroid
        
        nearest_node = nearest_nodes(terminal_graph, centroid, 1)
        graph.nodes[nearest_node[0][0]]['demand'] += int(ceil((od[1]['demand']-od[1]['supply'])/52))
        
    return graph

# Function to make the net demand of the graph equal to zero (condition for minimum cost flow algorithm)
def equalize_demand_supply(graph):
    sumdem=0 
    # Calculate the total demand
    for u,attr in graph.nodes(data=True):
        if attr['demand'] !=0:
            sumdem+=int(attr['demand'])

    # Add a source_sink node with demand equal to negative the total demand, to make the demand and supply equal
    graph.add_node('source_sink', demand=int(-sumdem), pos=graph.nodes[0]['pos'])

    # Add edges from all nodes to the source_sink node
    for u, attr in graph.nodes(data=True):
        if u == 'source_sink':
            continue
        if not graph.has_edge(u, 'source_sink', 0):
            graph.add_edge(u,'source_sink', 0, weight=int(1e10))
        if not graph.has_edge('source_sink', u):
            graph.add_edge('source_sink', u, 0, weight=int(1e10))

    return graph

#Source: SA
def create_virtual_graph(graph):
    max_weight_graph = max(attr['weight'] for _, _, attr in G.edges(data=True))
    print('Max weight: '+str(max_weight_graph))
    max_capacity_graph = max(attr['capacity'] for _, _, attr in G.edges(data=True))
    print('Max capacity: '+str(max_capacity_graph))

    # create a virtual node with dummy nodes
    graph_v=graph.copy()
    # convert to int
    for u, v, key, attr in G.edges(keys=True, data=True):
        graph_v.add_edge((str(u) + '_d'), (str(v) + '_d'), **attr)

    for u in G.nodes:
        graph_v.add_edge(u,(str(u) + '_d'),capacity=max_capacity_graph*100,weight=int(round(1e10,0)))
        graph_v.add_edge((str(u) + '_d'),u,capacity=max_capacity_graph*100,weight=0)

    # verify capacities, weights and demands are integers
    edge_capacities_types, edge_weights_types, node_demands_types = inspect_graph(graph_v)
    print("Edge Capacities Types:", set(edge_capacities_types))
    print("Edge Weights Types:", set(edge_weights_types))
    print("Node Demands Types:", set(node_demands_types))
    if {type(int())} == set(list(edge_capacities_types) + list(edge_weights_types) + list(node_demands_types)):
        print('Success: only int type values')
    else: 
        print('Warning! Not all values are integers')

    return graph_v

# Function to intersect the assets with hazard polygons
def process_hazard_indirect(single_footprint, assets, geom_dict):
    hazard_name = single_footprint.parts[-1].split('.')[0]
    # load hazard map
    hazard_map = ds.read_flood_map(single_footprint)


    # convert hazard data to epsg 3857
    if '.shp' or '.geojson' in str(hazard_map):
        hazard_map=gpd.read_file(hazard_map).to_crs(3857)[['geometry']] #take only necessary columns (geometry)
    else:
        hazard_map = gpd.GeoDataFrame(hazard_map).set_crs(4326).to_crs(3857)

    # make geometries valid
    hazard_map['geometry'] = hazard_map['geometry'].apply(lambda x: make_valid(x) if not is_valid(x) else x)

    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f'{timestamp} - Coarse overlay of hazard map with assets...')

    # coarse overlay of hazard map with assets (filter out assets that do not overlay with hazard map)
    intersected_assets=ds.overlay_hazard_assets(hazard_map,assets)
    overlay_assets = pd.DataFrame(intersected_assets.T,columns=['asset','hazard_point'])

    # numpify hazard map
    hazard_numpified = hazard_map.to_numpy() #.drop('w_depth_u', axis=1).to_numpy()
    disrupted_asset_length = {}
    # loop through assets in the same area as hazard map and get damage per asset
    for asset in tqdm(overlay_assets.groupby('asset'),total=len(overlay_assets.asset.unique())): #group asset items for different hazard points per asset and get total number of unique assets
        # retrieve asset geometry and do fine overlay
        asset_geom = geom_dict[asset[0]]              

        # find the exact hazard overlays:
        get_hazard_points = hazard_numpified[asset[1]['hazard_point'].values] 
        get_hazard_points[shapely.intersects(get_hazard_points[0][0],asset_geom)]

        # estimate damage
        if len(get_hazard_points) == 0: # no overlay of asset with hazard
            print('length of get_hazard_points is 0')       

        else:
            if asset_geom.geom_type == 'LineString':
                overlay_meters = shapely.length(shapely.intersection(get_hazard_points[0][0],asset_geom)) # get the length of exposed meters per hazard cell
                disrupted_asset_length[asset[0]]=np.sum(overlay_meters) # sum the total length of exposed meters

    return disrupted_asset_length

def calculate_new_paths(graph0, shortest_paths, disrupted_edges):
    graph=graph0.copy()
    for u,v in set(disrupted_edges):
        graph.remove_edge(u,v,0)
        
    disrupted_shortest_paths={}
    for (origin,destination), (nodes_in_spath,demand) in shortest_paths.items():
        edges_in_spath=[(nodes_in_spath[i],nodes_in_spath[i+1]) for i in range(len(nodes_in_spath)-1)]
        if set(disrupted_edges).isdisjoint(edges_in_spath):
            continue
        else:
            try:
                disrupted_shortest_paths[(origin,destination)] = (nx.shortest_path(graph, origin, destination, weight='weight'), demand)
            except nx.NetworkXNoPath:
                print(f'No path between {origin} and {destination}. Cannot ship by train.')
                disrupted_shortest_paths[(origin,destination)] = (None, demand)
                continue
    
    return disrupted_shortest_paths

# Function to calculate the disrupted flow in the network
def calculate_disrupted_mcf(graph, shortest_paths, disrupted_edges, flow_dict):
    for u,v in disrupted_edges:
        graph.edges[u,v,0]['capacity']=int(0)
    
    change_in_flow={}

    for (origin,destination), (nodes_in_spath,demand) in shortest_paths.items():
        edges_in_spath=[(nodes_in_spath[i],nodes_in_spath[i+1]) for i in range(len(nodes_in_spath)-1)]
        if set(disrupted_edges).isdisjoint(edges_in_spath):
            continue
        else:
            graph.nodes[origin]['demand']=int(-demand)
            graph.nodes[destination]['demand']=int(demand)
            mcf=nx.min_cost_flow(graph)
            for u, vs in mcf.items():
                for v, flow in vs.items():
                    d_flow = flow[0]-flow_dict[(origin,destination)][u][v][0]
                    if d_flow != 0:
                        change_in_flow[(origin,destination),(u,v)] = d_flow
                            
                
            # No need to repeat for each disrupted edge in path.
            break

    return change_in_flow

# Function to calculate the economic impact of flow disruptions
def calculate_economic_impact(graph, delta_flow, average_train_load_tons, average_train_cost_per_ton_km, average_road_cost_per_ton_km):
    # Initialize the economic impact variable
    economic_impact = 0
    virtual_reduction = []
    # Loop through the edges where there is a change in flow
    for ((origin, destination),(u,v)), d_flow in delta_flow.items():
        # if 'source_sink' in str(u) or 'source_sink' in str(v):
        #     continue
        if str(u).split('_')[0] == str(v).split('_')[0]:
            continue

        # For edges that have an increase in flow, calculate the economic impact of the disruption
        if d_flow > 0:
            # If the edge is between two dummy nodes, the cost of alternate transport mode is considered (road)
            if str(u).split('_')[-1] == 'd' and str(v).split('_')[-1] == 'd':
                economic_impact += d_flow*average_train_load_tons*(average_road_cost_per_ton_km - average_train_cost_per_ton_km)*(graph.edges[u,v,0]['length']/1000)
            
            # If the edge is between to nodes in the main network, the cost of the train is considered
            elif type(u)==int and type(v)==int:
                economic_impact += d_flow*average_train_load_tons*average_train_cost_per_ton_km*(graph.edges[u,v,0]['length']/1000)
            else:
                print(f'Error in {u,v}')
        
        # For edges that have a decrease in flow, the cost is subtracted (since d_flow is negative)
        #TODO What should happen when flow through dummy nodes decreases?
        if d_flow < 0:
            if type(u)==int and type(v)==int:
                economic_impact += d_flow*average_train_load_tons*average_train_cost_per_ton_km*(graph.edges[u,v,0]['length']/1000)
            elif str(u).split('_')[-1] == 'd' and str(v).split('_')[-1] == 'd':
                virtual_reduction.append((u,v))
             
            else:
                print(f'Error in {u,v}')
            
    if len(virtual_reduction)>0:
        print(f'Flow decrease between dummy nodes: {virtual_reduction}. \nNo cost is considered.')

    return economic_impact

def calculate_economic_impact_shortest_paths(graph, shortest_paths, disrupted_shortest_paths, average_train_load_tons, average_train_cost_per_ton_km, average_road_cost_per_ton_km):
    # Initialize the economic impact variable
    economic_impact = 0
    # Loop through the edges where there is a change in flow
    for (origin, destination), (nodes_in_path, demand) in disrupted_shortest_paths.items():
        length_old_path=0
        for i in range(len(shortest_paths[(origin, destination)][0])-1):
            length_old_path += graph.edges[shortest_paths[(origin, destination)][0][i], shortest_paths[(origin, destination)][0][i+1], 0]['length']/1000
                     
        if (nodes_in_path is None) or ('_d' in str(nodes_in_path)):
            economic_impact += demand*average_train_load_tons*(average_road_cost_per_ton_km-average_train_cost_per_ton_km)*length_old_path
            continue


        else:
            length_new_path=0
            for i in range(len(nodes_in_path)-1):
                length_new_path += graph.edges[nodes_in_path[i], nodes_in_path[i+1], 0]['length']/1000
            economic_impact += demand*average_train_load_tons*average_train_cost_per_ton_km*(length_new_path-length_old_path)
        

    return economic_impact

#TODO: remove if not used
def inspect_graph(graph):
    edge_capacities_types = []
    edge_weights_types = []
    node_demands_types = []

    for _, _, attr in graph.edges(data=True):
        if 'capacity' in attr:
            edge_capacities_types.append(type(attr['capacity']))
        if 'weight' in attr:
            edge_weights_types.append(type(attr['weight']))

    for _, attr in graph.nodes(data=True):
        if 'demand' in attr:
            node_demands_types.append(type(attr['demand']))

    return edge_capacities_types, edge_weights_types, node_demands_types

# %%
# Read exposure data (OSM, OpenStreetMap contributors (2024) / osm-flex)
assets_path = data_path / asset_data
assets = gpd.read_file(assets_path)
assets = gpd.GeoDataFrame(assets).set_crs(4326).to_crs(3857)
print(f"{len(assets)} assets loaded.")
# Out:
# 126925 assets loaded.

# %%
# Filter assets to only include railways
assets = assets.loc[assets.geometry.geom_type == 'LineString']
assets = assets.rename(columns={'railway' : 'asset'})
assets = assets[assets['asset']=='rail']
assets = assets[assets['railway:traffic_mode']!='"passenger"']
assets = assets.reset_index(drop=True)
print(f"{len(assets)} railway freight assets found.")

# Add buffer to assets to do area intersect and create dictionaries for quicker lookup
buffered_assets = ds.buffer_assets(assets)
geom_dict = assets['geometry'].to_dict()
type_dict = assets['asset'].to_dict()
# Out:
# 114036 railway freight assets found.

# %%
from shapely.geometry import LineString
# Round coordinates to 0 decimal places to avoid GEOSException: TopologyException: side location conflict at x, y
def round_coordinates(line):
    rounded_coords = []
    for coord in line.coords:
        rounded_coords.append((round(coord[0], 0), round(coord[1], 0)))
    return LineString(rounded_coords)

geoms=[]
for geom in assets['geometry']:
    geoms.append(round_coordinates(geom))

assets['geometry']=geoms

# %%
import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    #Source: Asgarpour/snkit
    # Create a railway networks with possible terminal nodes. This returns a complex network, as includes the rail tracks with the highest level of detail.
    aggregation_range = 0.08 # in km
    complex_rail_network = get_rail_network_with_terminals(network_gdf=assets, aggregation_range=aggregation_range)

# %%
with warnings.catch_warnings():
    try:
        warnings.simplefilter("ignore")
        merged_rail_network = merge_edges(network=complex_rail_network, excluded_edge_types=['bridge', 'tunnel']) #Must add network= to pass excluded_edge_types as a keyword argument

        # Number of nodes and edges reduced
        print(f"Difference in node counts: {complex_rail_network.nodes.shape[0] - merged_rail_network.nodes.shape[0]}")
        print(f"Difference in node counts %: {round(100*(complex_rail_network.nodes.shape[0] - merged_rail_network.nodes.shape[0])/complex_rail_network.nodes.shape[0], 0)}")
        print(f"Difference in edge counts: {complex_rail_network.edges.shape[0] - merged_rail_network.edges.shape[0]}")
        print(f"Difference in edge counts %: {round(100*(complex_rail_network.edges.shape[0] - merged_rail_network.edges.shape[0])/complex_rail_network.edges.shape[0], 0)}")
    except Exception as e:
        print(f'Exception: {e}')
        print('Skipping simplification step.')
        merged_rail_network=complex_rail_network
    
    merged_rail_graph = _network_to_nx(merged_rail_network)
# Out:
# Difference in node counts: 23779
# Difference in node counts %: 18.0
# Difference in edge counts: 24194
# Difference in edge counts %: 17.0

# %%
merged_rail_graph = _network_to_nx(merged_rail_network)

G=nx.MultiDiGraph(merged_rail_graph)

# Initialise demand and give position to nodes
for _, attr in G.nodes(data=True):
    attr['demand'] = int(0)
    attr['pos'] = (attr['geometry'].x, attr['geometry'].y)

bbox_shape=box(*get_bbox(G))

# %%
# Set weights for flow model
G = set_edge_weights(assets, G)

# %%
# Load route data
route_data_source='C:/Data/interim/route_traffic_DEU_net_seg20.csv'
route_data = pd.read_csv(route_data_source)

# Drop rows where 'geometry_from' and 'geometry_to' are NaN
route_data = route_data.loc[route_data['geometry_from'].notnull()]
route_data = route_data.loc[route_data['geometry_to'].notnull()]

# Convert 'geometry_from' and 'geometry_to' columns to shapely geometry
route_data = route_data.loc[route_data['geometry_from'] != route_data['geometry_to']]

# Filter route data to only include routes that start and end the bounding box of the graph
route_data = route_data[route_data['geometry_from'].apply(lambda geom: bbox_shape.contains(wkt.loads(geom)))]
route_data = route_data[route_data['geometry_to'].apply(lambda geom: bbox_shape.contains(wkt.loads(geom)))]

# %%
# Set capacities for flow model
G, shortest_paths = set_edge_capacities(G, route_data, simplified=True)
# Out:
# No path between 105867 and 24456
# No path between 24456 and 93723
# No path between 22616 and 93722
# No path between 93729 and 8846
# No path between 12246 and 36269
# No path between 47051 and 47093
# No path between 68156 and 114644
# No path between 68156 and 30036
# No path between 68170 and 30036
# No path between 47051 and 129466
# No path between 93729 and 118254
# No path between 118254 and 120476
# No path between 47051 and 127707
# No path between 13304 and 126633
# No path between 124558 and 126633
# No path between 47051 and 124788
# No path between 109057 and 90711
# No path between 90711 and 96813
# No path between 107334 and 122212
# No path between 102287 and 122212
# No path between 122212 and 124788
# No path between 47051 and 107334
# No path between 107527 and 98845
# No path between 98987 and 128830
# No path between 71108 and 128830
# No path between 130111 and 130107
# No path between 130111 and 130109
# No path between 87913 and 130109
# No path between 87913 and 26202
# No path between 130110 and 130111
# No path between 122096 and 130111
# No path between 130111 and 111476
# No path between 111476 and 107145
# No path between 115798 and 107145
# No path between 39967 and 8223
# No path between 130111 and 88221
# No path between 112056 and 111806
# No path between 111806 and 75399
# No path between 99338 and 93722
# No path between 112108 and 36922
# No path between 8223 and 36922
# No path between 36922 and 105561
# No path between 8223 and 105563
# No path between 107452 and 8223
# No path between 8223 and 17894
# No path between 112108 and 8223
# No path between 111476 and 107145
# No path between 130111 and 107145
# No path between 128232 and 8223
# No path between 8223 and 39258
# No path between 13643 and 23106
# No path between 129373 and 6156
# No path between 104116 and 6156
# No path between 17336 and 73426
# No path between 88937 and 115464
# No path between 42359 and 115464
# No path between 120457 and 73426
# No path between 54813 and 73426
# No path between 116630 and 115404
# No path between 92298 and 99675
# No path between 39967 and 8223
# No path between 115798 and 8223
# No path between 112382 and 121346
# No path between 123130 and 121346
# No path between 92298 and 116630
# No path between 92298 and 116630
# No path between 59796 and 115404
# No path between 59745 and 115404
# No path between 59796 and 92298
# No path between 59796 and 115404
# No path between 126694 and 80356
# No path between 104116 and 126694
# No path between 122970 and 100060
# No path between 100060 and 128706
# No path between 127848 and 115464
# No path between 123130 and 128830
# No path between 98386 and 128891
# No path between 73426 and 54470
# No path between 73426 and 54470
# No path between 106873 and 84808
# No path between 127572 and 73426
# No path between 106914 and 84808
# No path between 5568 and 126507
# No path between 55869 and 5568
# No path between 84808 and 106914
# No path between 95617 and 110779
# No path between 73426 and 127572
# No path between 99482 and 119568
# No path between 123844 and 112551
# No path between 112551 and 102896
# No path between 126457 and 120721
# No path between 68843 and 120721
# No path between 68843 and 41617
# No path between 126457 and 121128
# No path between 14973 and 121128
# No path between 22258 and 14973
# No path between 120721 and 126457
# No path between 121779 and 126457
# No path between 121779 and 94522
# No path between 126457 and 27034
# No path between 14975 and 121128
# No path between 14975 and 29130
# No path between 109057 and 115700
# No path between 69002 and 115700
# No path between 97109 and 115700
# No path between 109057 and 90711
# No path between 95127 and 75621
# No path between 66997 and 95127
# No path between 69002 and 115700
# No path between 115700 and 109057
# No path between 115700 and 68993
# No path between 97109 and 115700
# No path between 92206 and 13223
# No path between 13223 and 92206
# No path between 92206 and 13223
# No path between 13223 and 92206
# No path between 93723 and 24456
# No path between 13223 and 97109
# No path between 13223 and 100898
# No path between 13223 and 97109
# No path between 13223 and 97109
# No path between 13223 and 97109
# No path between 75621 and 13223
# No path between 75621 and 13223
# No path between 13223 and 92206
# No path between 13223 and 92206
# No path between 13223 and 92206
# No path between 97109 and 13223
# No path between 96421 and 115700
# No path between 115700 and 96421
# No path between 96421 and 115700
# No path between 96421 and 115700
# No path between 71854 and 112447
# No path between 96421 and 115700
# No path between 115700 and 68993
# No path between 96421 and 115700
# No path between 9082 and 93723
# No path between 13223 and 97109
# No path between 97109 and 13223
# No path between 97109 and 13223
# No path between 13223 and 97109
# No path between 13223 and 96421
# No path between 13223 and 92206
# No path between 92206 and 13223
# No path between 24456 and 105867
# No path between 93723 and 24456
# No path between 93722 and 22616
# No path between 8846 and 93729
# No path between 36269 and 12246
# No path between 47093 and 47051
# No path between 114644 and 68156
# No path between 30036 and 68156
# No path between 30036 and 68170
# No path between 129466 and 47051
# No path between 118254 and 93729
# No path between 120476 and 118254
# No path between 127707 and 47051
# No path between 126633 and 13304
# No path between 126633 and 124558
# No path between 124788 and 47051
# No path between 90711 and 109057
# No path between 96813 and 90711
# No path between 122212 and 107334
# No path between 122212 and 102287
# No path between 124788 and 122212
# No path between 107334 and 47051
# No path between 98845 and 107527
# No path between 128830 and 98987
# No path between 128830 and 71108
# No path between 130107 and 130111
# No path between 130109 and 130111
# No path between 130109 and 87913
# No path between 26202 and 87913
# No path between 130111 and 130110
# No path between 130111 and 122096
# No path between 111476 and 130111
# No path between 107145 and 111476
# No path between 107145 and 115798
# No path between 8223 and 39967
# No path between 88221 and 130111
# No path between 111806 and 112056
# No path between 75399 and 111806
# No path between 93722 and 99338
# No path between 36922 and 112108
# No path between 36922 and 8223
# No path between 105561 and 36922
# No path between 105563 and 8223
# No path between 8223 and 107452
# No path between 8223 and 112108
# No path between 107145 and 111476
# No path between 107145 and 130111
# No path between 8223 and 128232
# No path between 39258 and 8223
# No path between 23106 and 13643
# No path between 6156 and 129373
# No path between 6156 and 104116
# No path between 73426 and 17336
# No path between 115464 and 88937
# No path between 115464 and 42359
# No path between 73426 and 120457
# No path between 73426 and 54813
# No path between 115404 and 116630
# No path between 99675 and 92298
# No path between 8223 and 39967
# No path between 8223 and 115798
# No path between 121346 and 112382
# No path between 121346 and 123130
# No path between 116630 and 92298
# No path between 115404 and 59796
# No path between 115404 and 59745
# No path between 92298 and 59796
# No path between 115404 and 59796
# No path between 80356 and 126694
# No path between 126694 and 104116
# No path between 100060 and 122970
# No path between 128706 and 100060
# No path between 115464 and 127848
# No path between 128830 and 123130
# No path between 128891 and 98386
# No path between 54470 and 73426
# No path between 54470 and 73426
# No path between 84808 and 106873
# No path between 73426 and 127572
# No path between 84808 and 106914
# No path between 126507 and 5568
# No path between 5568 and 55869
# No path between 106914 and 84808
# No path between 110779 and 95617
# No path between 127572 and 73426
# No path between 119568 and 99482
# No path between 112551 and 123844
# No path between 102896 and 112551
# No path between 120721 and 126457
# No path between 120721 and 68843
# No path between 41617 and 68843
# No path between 121128 and 126457
# No path between 121128 and 14973
# No path between 14973 and 22258
# No path between 126457 and 120721
# No path between 126457 and 121779
# No path between 94522 and 121779
# No path between 27034 and 126457
# No path between 121128 and 14975
# No path between 29130 and 14975
# No path between 115700 and 109057
# No path between 115700 and 69002
# No path between 115700 and 97109
# No path between 90711 and 109057
# No path between 75621 and 95127
# No path between 95127 and 66997
# No path between 115700 and 69002
# No path between 109057 and 115700
# No path between 68993 and 115700
# No path between 115700 and 97109
# No path between 13223 and 92206
# No path between 92206 and 13223
# No path between 13223 and 92206
# No path between 92206 and 13223
# No path between 24456 and 93723
# No path between 97109 and 13223
# No path between 100898 and 13223
# No path between 97109 and 13223
# No path between 97109 and 13223
# No path between 97109 and 13223
# No path between 13223 and 75621
# No path between 13223 and 75621
# No path between 92206 and 13223
# No path between 92206 and 13223
# No path between 92206 and 13223
# No path between 13223 and 97109
# No path between 115700 and 96421
# No path between 96421 and 115700
# No path between 115700 and 96421
# No path between 115700 and 96421
# No path between 112447 and 71854
# No path between 115700 and 96421
# No path between 68993 and 115700
# No path between 115700 and 96421
# No path between 93723 and 9082
# No path between 97109 and 13223
# No path between 13223 and 97109
# No path between 13223 and 97109
# No path between 97109 and 13223
# No path between 96421 and 13223
# No path between 92206 and 13223
# No path between 13223 and 92206

# %%
# Create initial virtual graph
G_v0=create_virtual_graph(G)
# Out:
# Max weight: 119546999
# Max capacity: 1
# Edge Capacities Types: {<class 'int'>}
# Edge Weights Types: {<class 'int'>}
# Node Demands Types: {<class 'int'>}
# Success: only int type values

# %%
G_v=G_v0.copy()

# %%
# Define the baseline return periods 
"""
Return period definitions for Rhineland Palatinate (DERP) based on the report by Rauthe M, et al. (2020):
_H_=10-25y 
_M_=100y
_L_=200y
"""
return_period_dict = {'_H_': 10,'_M_': 100,'_L_': 200}

# Add climate change: calculate the dynamic return periods based on flat increase factors. 
# This value has been catchment-specific with frequency increasing in some regions and decreasing in others. 
# It is reasonable that in the future, the frequency will continue to change differently by catchment.

increase_factor = {
    '_H_': (1.2+9.0)/2,
    '_M_': (1.2+9.0)/2,
    '_L_': (1.2+9.0)/2 #average of the range (1.2 to 9.0) based on change since 1900
}

num_years = 100
return_periods = calculate_dynamic_return_periods(return_period_dict, num_years, increase_factor)
return_periods
# Out:
# {'_H_': [10.0,
#   9.606147934678193,
#   9.242144177449168,
#   8.904719501335707,
#   8.59106529209622,
#   8.29875518672199,
#   8.025682182985554,
#   7.770007770007769,
#   7.53012048192771,
#   7.304601899196492,
#   7.092198581560283,
#   6.891798759476223,
#   6.702412868632708,
#   6.523157208088714,
#   6.353240152477763,
#   6.191950464396284,
#   6.038647342995168,
#   5.8927519151443715,
#   5.7537399309551205,
#   5.621135469364812,
#   5.4945054945054945,
#   5.37345513164965,
#   5.257623554153523,
#   5.146680391147709,
#   5.040322580645161,
#   4.938271604938271,
#   4.84027105517909,
#   4.746084480303749,
#   4.655493482309124,
#   4.568296025582457,
#   4.484304932735426,
#   4.403346543372963,
#   4.325259515570934,
#   4.249893752656184,
#   4.177109440267334,
#   4.1067761806981515,
#   4.038772213247173,
#   3.972983710766785,
#   3.909304143862392,
#   3.847633705271258,
#   3.7878787878787876,
#   3.729951510630362,
#   3.673769287288758,
#   3.6192544335866814,
#   3.566333808844508,
#   3.5149384885764494,
#   3.465003465003465,
#   3.4164673727365904,
#   3.369272237196765,
#   3.3233632436025253,
#   3.2786885245901636,
#   3.235198964736331,
#   3.192848020434227,
#   3.1515915537346357,
#   3.111387678904791,
#   3.0721966205837172,
#   3.0339805825242716,
#   2.9967036260113873,
#   2.960331557134399,
#   2.924831822170225,
#   2.890173410404624,
#   2.856326763781776,
#   2.8232636928289097,
#   2.7909572983533346,
#   2.7593818984547456,
#   2.7285129604365617,
#   2.698327037236913,
#   2.668801708033093,
#   2.6399155227032733,
#   2.6116479498563594,
#   2.5839793281653747,
#   2.5568908207619536,
#   2.5303643724696356,
#   2.504382669671926,
#   2.478929102627665,
#   2.4539877300613493,
#   2.429543245869776,
#   2.405580947798893,
#   2.3820867079561694,
#   2.3590469450342058,
#   2.3364485981308407,
#   2.314279102059708,
#   2.2925263640531863,
#   2.271178741766977,
#   2.25022502250225,
#   2.229654403567447,
#   2.209456473707468,
#   2.1896211955331726,
#   2.170138888888889,
#   2.151000215100021,
#   2.132196162046908,
#   2.1137180300147955,
#   2.0955574182732604,
#   2.0777062123415746,
#   2.0601565718994643,
#   2.0429009193054135,
#   2.025931928687196,
#   2.0092425155716294,
#   1.9928258270227182,
#   1.9766752322593397,
#   1.9607843137254901],
#  '_M_': [100.0,
#   96.06147934678194,
#   92.42144177449168,
#   89.04719501335708,
#   85.9106529209622,
#   82.98755186721992,
#   80.25682182985554,
#   77.7000777000777,
#   75.3012048192771,
#   73.04601899196494,
#   70.92198581560284,
#   68.91798759476224,
#   67.02412868632707,
#   65.23157208088715,
#   63.53240152477763,
#   61.91950464396286,
#   60.3864734299517,
#   58.927519151443725,
#   57.53739930955121,
#   56.21135469364812,
#   54.94505494505494,
#   53.734551316496514,
#   52.57623554153523,
#   51.4668039114771,
#   50.40322580645162,
#   49.38271604938272,
#   48.4027105517909,
#   47.460844803037496,
#   46.55493482309125,
#   45.682960255824575,
#   44.84304932735426,
#   44.03346543372964,
#   43.25259515570934,
#   42.49893752656184,
#   41.771094402673356,
#   41.06776180698152,
#   40.38772213247173,
#   39.72983710766786,
#   39.09304143862393,
#   38.47633705271258,
#   37.87878787878788,
#   37.299515106303616,
#   36.73769287288759,
#   36.19254433586682,
#   35.66333808844509,
#   35.149384885764505,
#   34.650034650034655,
#   34.16467372736591,
#   33.692722371967655,
#   33.23363243602526,
#   32.78688524590164,
#   32.35198964736331,
#   31.92848020434228,
#   31.515915537346366,
#   31.11387678904792,
#   30.721966205837177,
#   30.33980582524272,
#   29.96703626011388,
#   29.60331557134399,
#   29.248318221702252,
#   28.901734104046245,
#   28.563267637817766,
#   28.232636928289107,
#   27.909572983533355,
#   27.593818984547465,
#   27.285129604365626,
#   26.983270372369134,
#   26.688017080330933,
#   26.399155227032736,
#   26.116479498563596,
#   25.839793281653748,
#   25.568908207619536,
#   25.30364372469636,
#   25.043826696719265,
#   24.78929102627665,
#   24.5398773006135,
#   24.295432458697768,
#   24.055809477988937,
#   23.820867079561697,
#   23.590469450342063,
#   23.364485981308412,
#   23.142791020597084,
#   22.925263640531867,
#   22.711787417669772,
#   22.502250225022504,
#   22.296544035674472,
#   22.09456473707468,
#   21.89621195533173,
#   21.70138888888889,
#   21.510002151000215,
#   21.321961620469086,
#   21.13718030014796,
#   20.955574182732608,
#   20.77706212341575,
#   20.601565718994646,
#   20.42900919305414,
#   20.259319286871964,
#   20.092425155716295,
#   19.928258270227182,
#   19.7667523225934,
#   19.607843137254903],
#  '_L_': [200.0,
#   192.12295869356387,
#   184.84288354898337,
#   178.09439002671417,
#   171.8213058419244,
#   165.97510373443984,
#   160.51364365971108,
#   155.4001554001554,
#   150.6024096385542,
#   146.09203798392988,
#   141.84397163120568,
#   137.83597518952448,
#   134.04825737265415,
#   130.4631441617743,
#   127.06480304955527,
#   123.83900928792572,
#   120.7729468599034,
#   117.85503830288745,
#   115.07479861910242,
#   112.42270938729624,
#   109.89010989010988,
#   107.46910263299303,
#   105.15247108307047,
#   102.9336078229542,
#   100.80645161290325,
#   98.76543209876544,
#   96.8054211035818,
#   94.92168960607499,
#   93.1098696461825,
#   91.36592051164915,
#   89.68609865470852,
#   88.06693086745928,
#   86.50519031141869,
#   84.99787505312368,
#   83.54218880534671,
#   82.13552361396304,
#   80.77544426494346,
#   79.45967421533572,
#   78.18608287724786,
#   76.95267410542516,
#   75.75757575757576,
#   74.59903021260723,
#   73.47538574577518,
#   72.38508867173364,
#   71.32667617689017,
#   70.29876977152901,
#   69.30006930006931,
#   68.32934745473182,
#   67.38544474393531,
#   66.46726487205052,
#   65.57377049180327,
#   64.70397929472662,
#   63.85696040868456,
#   63.03183107469273,
#   62.22775357809584,
#   61.44393241167435,
#   60.67961165048544,
#   59.93407252022776,
#   59.20663114268798,
#   58.496636443404505,
#   57.80346820809249,
#   57.12653527563553,
#   56.465273856578214,
#   55.81914596706671,
#   55.18763796909493,
#   54.57025920873125,
#   53.96654074473827,
#   53.37603416066187,
#   52.79831045406547,
#   52.23295899712719,
#   51.679586563307495,
#   51.13781641523907,
#   50.60728744939272,
#   50.08765339343853,
#   49.5785820525533,
#   49.079754601227,
#   48.590864917395535,
#   48.111618955977875,
#   47.641734159123395,
#   47.180938900684126,
#   46.728971962616825,
#   46.28558204119417,
#   45.850527281063734,
#   45.423574835339544,
#   45.00450045004501,
#   44.593088071348944,
#   44.18912947414936,
#   43.79242391066346,
#   43.40277777777778,
#   43.02000430200043,
#   42.64392324093817,
#   42.27436060029592,
#   41.911148365465216,
#   41.5541242468315,
#   41.20313143798929,
#   40.85801838610828,
#   40.51863857374393,
#   40.18485031143259,
#   39.856516540454365,
#   39.5335046451868,
#   39.21568627450981]}

# %%
if 'collect_output' not in locals():
    collect_output_path = f'C:/Data/interim/collected_flood_runs/sample_collected_run.pkl'
    with open(collect_output_path, 'rb') as f:
        collect_output = pickle.load(f)

collect_output
# Out:
# {'flood_DERP_RW_H_4326_2080411370': {(37, 'F8.1'): (0.0, 6804.70524910867),
#   (317, 'F8.1'): (35681.36614604254, 183320.07231032426),
#   (318, 'F8.1'): (12694.772779722756, 91773.82987210897),
#   (320, 'F8.1'): (10501.288663949334, 47721.054899095056),
#   (359, 'F8.1'): (1694688.3299544218, 5169602.150739019),
#   (531, 'F8.1'): (4938.013851203248, 11007.983632391166),
#   (1122, 'F8.1'): (141142.7466311752, 678080.0877499741),
#   (1125, 'F8.1'): (726643.7091104591, 2471198.7550438214),
#   (1136, 'F8.1'): (14663.35847214106, 101679.47606096763),
#   (1140, 'F8.1'): (10505.763125255147, 38957.769375767646),
#   (1145, 'F8.1'): (112247.01885146243, 397397.07885508763),
#   (1147, 'F8.1'): (47372.74474048824, 184343.02015601346),
#   (1344, 'F8.1'): (2454.9455722645575, 12274.727126641936),
#   (1989, 'F8.1'): (53660.13253225429, 343759.40683026717),
#   (2441, 'F8.1'): (16452.33871267755, 48776.64195511594),
#   (2444, 'F8.1'): (19408.797030851336, 84722.06047424386),
#   (2445, 'F8.1'): (793078.6542875242, 3457412.3684191313),
#   (2580, 'F8.1'): (0.0, 5036.91179721698),
#   (3004, 'F8.1'): (10273.651173549417, 21173.019442623066)},
#  'flood_DERP_RW_H_4326_2080416200': {(156, 'F8.1'): (174266.10054197372,
#    285102.1587949132),
#   (1322, 'F8.1'): (197701.96985118047, 303832.47875460214)},
#  'flood_DERP_RW_H_4326_2080416210': {(360, 'F8.1'): (33708.023088147514,
#    158248.41047144923),
#   (446, 'F8.1'): (9681.736850583116, 42800.01794023439),
#   (564, 'F8.1'): (10173.536821839432, 21688.612140969843),
#   (572, 'F8.1'): (50249.36766471465, 74978.00665245415),
#   (677, 'F8.1'): (3688.5159146512146, 13892.402545527659),
#   (1097, 'F8.1'): (35164.47933851868, 68321.99489773999),
#   (1120, 'F8.1'): (25331.96614628638, 124131.34011771489),
#   (1302, 'F8.1'): (184871.57247835837, 197074.94637749516),
#   (1304, 'F8.1'): (51376.37142587306, 75486.65418875363),
#   (1312, 'F8.1'): (20473.852303388245, 31512.54460613448),
#   (1474, 'F8.1'): (5128.677189917127, 23306.969785306897),
#   (1496, 'F8.1'): (160634.64932415017, 178733.27374455953),
#   (1503, 'F8.1'): (0.0, 84931.70947986667),
#   (2415, 'F8.1'): (46572.129007294774, 46572.129007294774),
#   (2416, 'F8.1'): (37324.19516259164, 37324.19516259164),
#   (2438, 'F8.1'): (50473.15123823009, 94488.22962111396),
#   (2439, 'F8.1'): (0.0, 27878.581251554646),
#   (2448, 'F8.1'): (84235.91032972315, 107280.8983982169),
#   (2468, 'F8.1'): (11260.867486419782, 42074.994981462216),
#   (2471, 'F8.1'): (13505.005352000859, 62802.55879580078),
#   (2573, 'F8.1'): (23416.83674127467, 114990.45434498815),
#   (2589, 'F8.1'): (68498.01027428411, 95190.14301960016),
#   (2595, 'F8.1'): (7504.380316074125, 14915.623921335617),
#   (2788, 'F8.1'): (1289832.0494761304, 3942145.5435184194)},
#  'flood_DERP_RW_H_4326_2080418880': {(910, 'F8.1'): (117287.00620526672,
#    117287.00620526672),
#   (1256, 'F8.1'): (105524.55778993679, 106911.93691632358),
#   (2468, 'F8.1'): (0.0, 871.4547130519792),
#   (2471, 'F8.1'): (447.96327461321965, 447.96327461321965)},
#  'flood_DERP_RW_L_4326_2080411370': {(37, 'F8.1'): (543666.1778714762,
#    2458653.921374703),
#   (269, 'F8.1'): (121430.42426075842, 155089.526782688),
#   (314, 'F8.1'): (0.0, 112136.24587462629),
#   (315, 'F8.1'): (61372.40941099144, 86986.84086723377),
#   (316, 'F8.1'): (0.0, 1119.9755640708377),
#   (317, 'F8.1'): (184843.0662987347, 184843.0662987347),
#   (318, 'F8.1'): (2757758.7735236585, 4467438.008098764),
#   (319, 'F8.1'): (69456.25770469142, 169118.6730482688),
#   (320, 'F8.1'): (119656.08702404077, 145995.71677753996),
#   (321, 'F8.1'): (633711.6269743257, 2444420.760178655),
#   (322, 'F8.1'): (18388.995169052738, 95261.99863783302),
#   (323, 'F8.1'): (147881.54567411204, 715931.4425205912),
#   (352, 'F8.1'): (1202034.7823458319, 2432650.7498514126),
#   (359, 'F8.1'): (6718481.577066288, 6718481.577066288),
#   (530, 'F8.1'): (2222982.462475949, 8926368.402673941),
#   (531, 'F8.1'): (103906.27054160183, 162437.2586078733),
#   (545, 'F8.1'): (1057590.6220572717, 3835632.3842996135),
#   (546, 'F8.1'): (97585.65968990521, 139242.60221283967),
#   (547, 'F8.1'): (891307.4104583442, 3180157.2777889348),
#   (548, 'F8.1'): (20310.940147164445, 39036.447947066896),
#   (549, 'F8.1'): (770220.5000845835, 1127750.60397167),
#   (677, 'F8.1'): (466686.35345881927, 2417613.053828401),
#   (692, 'F8.1'): (1256807.2631235053, 6510740.292606069),
#   (693, 'F8.1'): (475034.1131607046, 1251789.693826691),
#   (943, 'F8.1'): (1708333.799111056, 8799467.954615155),
#   (1122, 'F8.1'): (731173.1834019311, 731173.1834019311),
#   (1123, 'F8.1'): (1467351.3803774207, 7601439.008150918),
#   (1124, 'F8.1'): (1424691.891219883, 7380446.606953537),
#   (1125, 'F8.1'): (2598459.635552079, 2598459.635552079),
#   (1126, 'F8.1'): (544551.4331130144, 2284133.6347935596),
#   (1127, 'F8.1'): (423543.6870424797, 2134203.078658014),
#   (1128, 'F8.1'): (557366.8704308139, 2887372.6684702015),
#   (1129, 'F8.1'): (120041.93700339062, 621862.953041871),
#   (1130, 'F8.1'): (278976.3840921958, 1426044.07194415),
#   (1131, 'F8.1'): (17244.72319748775, 39207.330230190426),
#   (1132, 'F8.1'): (2887138.8340638597, 13634969.33287431),
#   (1133, 'F8.1'): (734767.7567092172, 3806376.8245778875),
#   (1134, 'F8.1'): (844988.945294259, 4377364.560466748),
#   (1135, 'F8.1'): (464550.17426571884, 2383350.631541338),
#   (1136, 'F8.1'): (3231508.6612187894, 5532353.847466311),
#   (1137, 'F8.1'): (1434813.556785703, 4720523.590223564),
#   (1138, 'F8.1'): (20042.295898299784, 103826.72609409533),
#   (1139, 'F8.1'): (615647.8356958029, 3189290.26552458),
#   (1140, 'F8.1'): (128633.3194811772, 154984.17201455758),
#   (1141, 'F8.1'): (7929.781938009091, 11152.578954359582),
#   (1142, 'F8.1'): (484071.9714533307, 2376837.183853609),
#   (1143, 'F8.1'): (277589.26618415717, 1438018.1219262579),
#   (1144, 'F8.1'): (51255.6512508776, 84466.19740858546),
#   (1145, 'F8.1'): (4709064.218905016, 7596284.096881769),
#   (1146, 'F8.1'): (239373.87519802514, 1240047.8418431024),
#   (1147, 'F8.1'): (184343.02015601346, 184343.02015601346),
#   (1148, 'F8.1'): (18772.399217190425, 97248.17763106583),
#   (1150, 'F8.1'): (2052.908827897287, 157088.6811888268),
#   (1152, 'F8.1'): (1035450.8497429705, 1759469.1999272127),
#   (1153, 'F8.1'): (125500.7561639964, 579589.4927817472),
#   (1154, 'F8.1'): (2114.096059820641, 31020.560407786783),
#   (1156, 'F8.1'): (126998.47326618218, 225402.91726462304),
#   (1344, 'F8.1'): (100036.60332621918, 136344.0062945054),
#   (1346, 'F8.1'): (126315.97901214992, 160066.80797980813),
#   (1517, 'F8.1'): (1680872.3805164753, 5734657.390984936),
#   (1535, 'F8.1'): (27432.518600744268, 96503.23910710037),
#   (1536, 'F8.1'): (539015.4048733035, 905250.9555529894),
#   (1537, 'F8.1'): (1175434.6679001444, 3894286.556335893),
#   (1538, 'F8.1'): (30213.29755432941, 57391.38047637697),
#   (1539, 'F8.1'): (824055.8600360904, 1130966.2955027749),
#   (1540, 'F8.1'): (2941923.233235278, 13866578.563908594),
#   (1541, 'F8.1'): (25927.360665164037, 123184.76960790722),
#   (1989, 'F8.1'): (4674658.108809223, 7447213.198259287),
#   (1990, 'F8.1'): (88266.02450868145, 169104.6220709326),
#   (1991, 'F8.1'): (26694.72269562808, 34328.82387543871),
#   (1992, 'F8.1'): (34237.34096577788, 95536.96282319586),
#   (2193, 'F8.1'): (1081803.7701929763, 5604155.547115441),
#   (2194, 'F8.1'): (1807992.4894966418, 9366089.69050665),
#   (2195, 'F8.1'): (106454.75952215045, 551476.198854879),
#   (2196, 'F8.1'): (150298.75833443578, 778604.8111980966),
#   (2197, 'F8.1'): (448163.7712135779, 2321659.023257723),
#   (2198, 'F8.1'): (301628.92671923485, 1562552.719281558),
#   (2229, 'F8.1'): (0.0, 2111.6044132100233),
#   (2231, 'F8.1'): (5182.695330460372, 88997.57234757705),
#   (2232, 'F8.1'): (0.0, 48988.978630317186),
#   (2395, 'F8.1'): (31218.27831699327, 62602.59580000868),
#   (2396, 'F8.1'): (80962.49267054907, 325380.1599207035),
#   (2441, 'F8.1'): (754584.7457067186, 1762121.4167153467),
#   (2444, 'F8.1'): (1531458.0578670301, 2813742.8496392965),
#   (2445, 'F8.1'): (4108449.4824153227, 4108449.4824153227),
#   (2557, 'F8.1'): (1273852.9231454222, 4061542.4158518286),
#   (2558, 'F8.1'): (1042093.1401296075, 3521530.947898806),
#   (2559, 'F8.1'): (3264.9309628944848, 3264.9309628944848),
#   (2560, 'F8.1'): (229398.67460011918, 1188372.5035750803),
#   (2561, 'F8.1'): (300350.4830339941, 1131238.3796832447),
#   (2562, 'F8.1'): (275969.831279006, 1429628.8323370041),
#   (2563, 'F8.1'): (102331.81941453938, 530117.7988278838),
#   (2564, 'F8.1'): (155885.03325264112, 807543.8428720089),
#   (2565, 'F8.1'): (77664.68913929009, 402332.6692393651),
#   (2580, 'F8.1'): (644656.5507000419, 1577676.3023900995),
#   (2725, 'F8.1'): (16512.951754126418, 85543.37923561623),
#   (2726, 'F8.1'): (282586.9079090056, 1367119.7040861275),
#   (3004, 'F8.1'): (355376.3784576146, 355376.3784576146)},
#  'flood_DERP_RW_L_4326_2080416200': {(156, 'F8.1'): (567731.448029813,
#    692360.4369345872),
#   (186, 'F8.1'): (77660.74765307514, 110022.4705224338),
#   (1321, 'F8.1'): (89577.32419883207, 131214.63418934916),
#   (1322, 'F8.1'): (554131.2798265446, 722902.4414407114)},
#  'flood_DERP_RW_L_4326_2080416210': {(136, 'F8.1'): (2305463.2156340005,
#    9553597.904932994),
#   (147, 'F8.1'): (17075.241067225455, 21926.931532194616),
#   (153, 'F8.1'): (481192.3215825999, 1480375.4470965602),
#   (353, 'F8.1'): (81593.24824515314, 122809.39840765504),
#   (357, 'F8.1'): (112158.09308191578, 135781.24509666406),
#   (360, 'F8.1'): (174620.39768824217, 174620.39768824217),
#   (407, 'F8.1'): (132525.79190326532, 136205.15416320888),
#   (408, 'F8.1'): (48251.65214724828, 251718.94204578473),
#   (410, 'F8.1'): (918036.4077669397, 1171185.3648019787),
#   (411, 'F8.1'): (17175.23241822446, 32257.787509363723),
#   (445, 'F8.1'): (20688.701959597114, 82630.57472082911),
#   (446, 'F8.1'): (9343278.985106857, 22764402.06763233),
#   (447, 'F8.1'): (0.0, 26287.219528425114),
#   (448, 'F8.1'): (0.0, 196938.28460235085),
#   (449, 'F8.1'): (5508.879562617149, 16666.568763392985),
#   (450, 'F8.1'): (8780.65680927002, 151769.47994063006),
#   (451, 'F8.1'): (5519519.640068535, 19599322.869294263),
#   (452, 'F8.1'): (6677.412802878995, 33155.13547958918),
#   (555, 'F8.1'): (7826.5870922074555, 512375.09892556304),
#   (563, 'F8.1'): (18080583.35852214, 31173603.05196395),
#   (564, 'F8.1'): (70312.93713556608, 260198.7648805146),
#   (572, 'F8.1'): (155187.28419589365, 169045.09516355622),
#   (635, 'F8.1'): (4152554.161976176, 14153981.579422198),
#   (638, 'F8.1'): (3287.4361037348917, 188971.39466936304),
#   (677, 'F8.1'): (3110368.7603105297, 14508995.96075977),
#   (1091, 'F8.1'): (1132616.6222998316, 4234040.025773648),
#   (1092, 'F8.1'): (0.0, 17263.68594653086),
#   (1093, 'F8.1'): (11482827.055371832, 20997485.136798933),
#   (1094, 'F8.1'): (133119.82006758198, 663369.2523288084),
#   (1095, 'F8.1'): (159529.78337388817, 203945.13956998728),
#   (1096, 'F8.1'): (1009309.6014312463, 1964525.685282006),
#   (1097, 'F8.1'): (10508198.915982323, 23369862.234384023),
#   (1098, 'F8.1'): (65458.68469355131, 226339.71683434106),
#   (1099, 'F8.1'): (50422.24009447358, 88012.74427492164),
#   (1100, 'F8.1'): (0.0, 207496.4027839705),
#   (1101, 'F8.1'): (5314.686013000711, 31632.267142853172),
#   (1102, 'F8.1'): (0.0, 134702.21565800637),
#   (1104, 'F8.1'): (68488.61437766618, 112827.70798970404),
#   (1105, 'F8.1'): (17076.563434948785, 63478.363840115075),
#   (1109, 'F8.1'): (126286.61417949176, 150356.7541989094),
#   (1113, 'F8.1'): (22797.244654459755, 59886.94122721452),
#   (1118, 'F8.1'): (146607.46910646406, 146607.46910646406),
#   (1119, 'F8.1'): (4349109.5214887345, 14159879.61441991),
#   (1120, 'F8.1'): (197539.54055870758, 197539.54055870758),
#   (1121, 'F8.1'): (45241.73570232903, 276210.1549274302),
#   (1126, 'F8.1'): (2770945.860899093, 14190148.267751258),
#   (1262, 'F8.1'): (8932.864010316696, 14959.71423112107),
#   (1268, 'F8.1'): (4434.971562114001, 98167.31857098934),
#   (1269, 'F8.1'): (4510.723910125571, 96863.53353204054),
#   (1277, 'F8.1'): (158367.25536025525, 319807.77205501136),
#   (1284, 'F8.1'): (257208.1655531785, 573701.3471785833),
#   (1299, 'F8.1'): (3813.3012643606817, 10901.284438803907),
#   (1302, 'F8.1'): (255898.2344865616, 319668.67287009343),
#   (1303, 'F8.1'): (32212.929787076184, 166875.24496506446),
#   (1304, 'F8.1'): (159934.84284901328, 168722.36407591938),
#   (1305, 'F8.1'): (316769.2884958664, 1001585.6554660676),
#   (1306, 'F8.1'): (2277842.867905833, 6053792.493928835),
#   (1307, 'F8.1'): (1533285.4287606757, 7542964.857387211),
#   (1308, 'F8.1'): (2725777.3481537076, 9465436.90545431),
#   (1310, 'F8.1'): (166130.3745528379, 860618.612864118),
#   (1311, 'F8.1'): (0.0, 86562.40205345677),
#   (1312, 'F8.1'): (101251.27603704424, 278416.4734238124),
#   (1313, 'F8.1'): (2174582.035778546, 9981627.687602289),
#   (1314, 'F8.1'): (1382761.4645467899, 5264070.078520985),
#   (1315, 'F8.1'): (0.0, 8454.743372304796),
#   (1474, 'F8.1'): (91302.50467492884, 91302.50467492884),
#   (1476, 'F8.1'): (21992.081590031747, 28767.485769612005),
#   (1495, 'F8.1'): (658904.7283732401, 2686667.33313656),
#   (1496, 'F8.1'): (258208.2392423428, 319532.7865863934),
#   (1497, 'F8.1'): (32722.25354358049, 169513.73600561806),
#   (1498, 'F8.1'): (2659247.550309795, 9155229.08867006),
#   (1503, 'F8.1'): (2608030.918542905, 3639051.257851332),
#   (1528, 'F8.1'): (523383.20441559405, 2177358.6247169157),
#   (1529, 'F8.1'): (571936.9695702087, 1315755.7157705058),
#   (1530, 'F8.1'): (249588.28577606013, 1001927.1816115023),
#   (1531, 'F8.1'): (4396156.986072929, 5462517.707019815),
#   (1532, 'F8.1'): (645478.7595280493, 2695179.258619918),
#   (1533, 'F8.1'): (148544.62141091382, 319318.81902718503),
#   (1534, 'F8.1'): (172287.60365243035, 756532.1483455681),
#   (1542, 'F8.1'): (1534848.1109588235, 5630273.841703251),
#   (1543, 'F8.1'): (1254600.6858311538, 5552047.602937795),
#   (1802, 'F8.1'): (105386.15779858138, 545940.4349374281),
#   (1936, 'F8.1'): (3021889.4240390384, 4097842.9946875023),
#   (2199, 'F8.1'): (1577366.8776352098, 4101241.281611805),
#   (2298, 'F8.1'): (816525.8400492746, 3262871.200057232),
#   (2408, 'F8.1'): (0.0, 104760.0856945248),
#   (2410, 'F8.1'): (395608.26658246183, 2049401.49289491),
#   (2415, 'F8.1'): (2260101.0619461513, 9921774.44420296),
#   (2416, 'F8.1'): (2225703.7240755977, 9440761.930209752),
#   (2417, 'F8.1'): (18910513.638520047, 28670628.90871941),
#   (2433, 'F8.1'): (310306.98615593393, 991683.0102906309),
#   (2434, 'F8.1'): (6019143.141061163, 7309706.457632075),
#   (2437, 'F8.1'): (241792.07486412305, 314552.0478724292),
#   (2438, 'F8.1'): (1089735.9284895584, 1619318.310648311),
#   (2439, 'F8.1'): (457832.4802195702, 793347.4528586975),
#   (2440, 'F8.1'): (59746.1365326743, 429082.9410646213),
#   (2442, 'F8.1'): (952978.9076269879, 3906747.9140262273),
#   (2446, 'F8.1'): (1719162.23139446, 5784584.31495563),
#   (2447, 'F8.1'): (1268086.7828789128, 6280232.307727145),
#   (2448, 'F8.1'): (6868215.435922058, 7597954.617856153),
#   (2468, 'F8.1'): (1917389.421606429, 3781102.774235242),
#   (2471, 'F8.1'): (1889524.6748851622, 5226415.879009984),
#   (2537, 'F8.1'): (1218898.5513727793, 4951469.939803431),
#   (2538, 'F8.1'): (1463706.3388626762, 6043120.63642894),
#   (2539, 'F8.1'): (796850.2681456143, 2574586.280892516),
#   (2570, 'F8.1'): (2278477.7590437992, 2528175.137603393),
#   (2571, 'F8.1'): (2439686.56586825, 2514052.398608815),
#   (2572, 'F8.1'): (950099.5138433286, 2586039.821404539),
#   (2573, 'F8.1'): (1509656.2151047075, 4220157.130080653),
#   (2574, 'F8.1'): (298155.7217203044, 469578.75372522825),
#   (2575, 'F8.1'): (3981157.988418027, 6629004.118683934),
#   (2576, 'F8.1'): (317593.7561818235, 438678.8489876955),
#   (2577, 'F8.1'): (3721683.4692971655, 6661761.681835031),
#   (2578, 'F8.1'): (390625.59509728034, 1285059.510519072),
#   (2579, 'F8.1'): (397024.05805373256, 1278300.6725310525),
#   (2581, 'F8.1'): (1298615.4114937526, 5185239.125198398),
#   (2582, 'F8.1'): (183741.85334629248, 951852.780550221),
#   (2583, 'F8.1'): (0.0, 161398.4022844909),
#   (2585, 'F8.1'): (0.0, 23391.69232410747),
#   (2586, 'F8.1'): (378717.69668995123, 1220259.4454211243),
#   (2587, 'F8.1'): (1079213.2034282575, 5409740.0509448685),
#   (2589, 'F8.1'): (6415562.47885583, 7898260.828872622),
#   (2590, 'F8.1'): (4982379.718110196, 7351552.093666583),
#   (2591, 'F8.1'): (3889.086087509543, 22197.1397765913),
#   (2592, 'F8.1'): (159902.1992003465, 189169.52110028034),
#   (2593, 'F8.1'): (98174.17409709343, 148921.81150983667),
#   (2594, 'F8.1'): (258741.7418979706, 658605.9650880281),
#   (2595, 'F8.1'): (149203.03156007314, 155958.05664039767),
#   (2596, 'F8.1'): (43800.104121199154, 368567.45654129604),
#   (2597, 'F8.1'): (1765397.1008903505, 6677588.998700596),
#   (2782, 'F8.1'): (78369.89470531579, 438989.82643735),
#   (2783, 'F8.1'): (493340.42247627577, 2390438.7994550397),
#   (2788, 'F8.1'): (4621840.321706884, 4621840.321706884),
#   (2789, 'F8.1'): (0.0, 41916.93246932966),
#   (2790, 'F8.1'): (373083.6140673229, 1868332.2021508093),
#   (2791, 'F8.1'): (760352.8239695416, 1881861.1433243311),
#   (2792, 'F8.1'): (1075563.9760610964, 3367898.981330485),
#   (2793, 'F8.1'): (480361.945866476, 513932.2672962477),
#   (2794, 'F8.1'): (734537.3878219468, 3505212.8365650824),
#   (2795, 'F8.1'): (176711.12901891538, 372802.178974311),
#   (2796, 'F8.1'): (577686.535432202, 2992636.2721575354),
#   (2797, 'F8.1'): (477883.8407254225, 477883.8407254225),
#   (2798, 'F8.1'): (445519.5001631749, 445519.5001631749),
#   (2799, 'F8.1'): (3894322.776343214, 5040172.355224957),
#   (2800, 'F8.1'): (3018189.7338984837, 4228499.993106391),
#   (2837, 'F8.1'): (724526.4034047811, 1528890.3257419807),
#   (2838, 'F8.1'): (1276331.6984455239, 1276331.6984455239),
#   (2839, 'F8.1'): (5424596.439119987, 5442798.790532079),
#   (2840, 'F8.1'): (4904702.012445941, 4968075.3202120485),
#   (2841, 'F8.1'): (332547.20883194375, 1695479.1452808613),
#   (2842, 'F8.1'): (571836.2386540881, 585352.9450272504),
#   (3015, 'F8.1'): (0.0, 78473.80594712094),
#   (3052, 'F8.1'): (394620.0149434133, 1427608.4361155084),
#   (3179, 'F8.1'): (34938.038708867454, 77254.60358136377),
#   (3180, 'F8.1'): (46608.14889295622, 114610.13353288762)},
#  'flood_DERP_RW_L_4326_2080418880': {(162, 'F8.1'): (173687.7591530978,
#    213316.76082630566),
#   (909, 'F8.1'): (59373.96056388692, 68882.3389611726),
#   (910, 'F8.1'): (119100.72929966675, 119100.72929966675),
#   (1253, 'F8.1'): (116346.02778876445, 148961.39989196815),
#   (1256, 'F8.1'): (110560.6628886125, 111948.04201499929),
#   (1257, 'F8.1'): (148459.5225187313, 183865.7268568391),
#   (1258, 'F8.1'): (53856.864790331514, 53856.864790331514),
#   (1260, 'F8.1'): (113771.44848290423, 138569.44933996757),
#   (2468, 'F8.1'): (1074764.110731124, 3550968.597671571),
#   (2471, 'F8.1'): (1106264.2612607111, 3561897.2020599525)},
#  'flood_DERP_RW_M_4326_2080411370': {(37, 'F8.1'): (35483.58764218136,
#    77196.03965774908),
#   (269, 'F8.1'): (20911.667014839255, 48636.006384549015),
#   (315, 'F8.1'): (7400.408286833554, 28691.706889823803),
#   (317, 'F8.1'): (184843.0662987347, 184843.0662987347),
#   (318, 'F8.1'): (730123.6151879219, 1899833.2004805654),
#   (320, 'F8.1'): (82461.72205393708, 100021.47678164006),
#   (359, 'F8.1'): (6718481.577066287, 6718481.577066287),
#   (531, 'F8.1'): (52979.21885946059, 68921.46179488681),
#   (546, 'F8.1'): (14752.67779163965, 51389.620716743666),
#   (547, 'F8.1'): (0.0, 2100.293074307847),
#   (677, 'F8.1'): (0.0, 11149.56625728663),
#   (692, 'F8.1'): (0.0, 2339.2755627855586),
#   (943, 'F8.1'): (0.0, 27666.988526579677),
#   (1122, 'F8.1'): (731173.1834019311, 731173.1834019311),
#   (1123, 'F8.1'): (0.0, 119498.37142189725),
#   (1124, 'F8.1'): (0.0, 155575.0511717409),
#   (1125, 'F8.1'): (2598459.635552079, 2598459.635552079),
#   (1126, 'F8.1'): (470.3987051817667, 94402.05680142403),
#   (1128, 'F8.1'): (0.0, 3580.8075747452635),
#   (1132, 'F8.1'): (729.038169155192, 996342.1553290632),
#   (1133, 'F8.1'): (0.0, 19692.229572855023),
#   (1134, 'F8.1'): (0.0, 63275.14635607113),
#   (1136, 'F8.1'): (817660.0225460157, 1895857.15186649),
#   (1137, 'F8.1'): (3923.6059230115516, 31543.267501605726),
#   (1139, 'F8.1'): (0.0, 57109.88115128884),
#   (1140, 'F8.1'): (84598.00970784196, 102165.24563052852),
#   (1144, 'F8.1'): (2044.1819216531594, 5851.601184497626),
#   (1145, 'F8.1'): (2382554.5128027946, 3764481.687580083),
#   (1146, 'F8.1'): (0.0, 38119.71512927208),
#   (1147, 'F8.1'): (184343.02015601346, 184343.02015601346),
#   (1344, 'F8.1'): (50920.51319663476, 80855.3318666735),
#   (1346, 'F8.1'): (22021.856120974462, 26915.605577174174),
#   (1540, 'F8.1'): (0.0, 623328.27761421),
#   (1989, 'F8.1'): (2164824.21930454, 3537142.1734222663),
#   (2193, 'F8.1'): (0.0, 127211.62662354187),
#   (2194, 'F8.1'): (0.0, 75776.59524439786),
#   (2396, 'F8.1'): (0.0, 20516.856380892383),
#   (2441, 'F8.1'): (288895.44551730173, 346516.9159863425),
#   (2444, 'F8.1'): (356533.4858550965, 690748.8648345213),
#   (2445, 'F8.1'): (4108449.4824153227, 4108449.4824153227),
#   (2564, 'F8.1'): (0.0, 775.7409074938753),
#   (2580, 'F8.1'): (179208.51801001138, 313555.73769485),
#   (3004, 'F8.1'): (149502.5966017206, 315903.23342996906)},
#  'flood_DERP_RW_M_4326_2080416200': {(156, 'F8.1'): (242943.92822972476,
#    356128.2804394477),
#   (186, 'F8.1'): (8997.632174464734, 11247.040748713842),
#   (1321, 'F8.1'): (4477.6566679128955, 8284.871123945728),
#   (1322, 'F8.1'): (259377.14648777898, 368168.55112049176)},
#  'flood_DERP_RW_M_4326_2080416210': {(136, 'F8.1'): (0.0, 558297.3180266875),
#   (353, 'F8.1'): (9303.070992519557, 16280.375847043402),
#   (357, 'F8.1'): (17665.45461994103, 82581.11674753357),
#   (360, 'F8.1'): (174620.39768824214, 174620.39768824214),
#   (407, 'F8.1'): (110648.9472595285, 123214.34544045909),
#   (408, 'F8.1'): (74.6798020650701, 386.8698173660359),
#   (446, 'F8.1'): (153918.89834758916, 3014629.444709998),
#   (451, 'F8.1'): (77034.87564882792, 2935753.6664337297),
#   (563, 'F8.1'): (110795.959520864, 5139628.578363284),
#   (564, 'F8.1'): (22306.565198563818, 24889.84433389746),
#   (572, 'F8.1'): (116310.73131561, 153780.7881292529),
#   (635, 'F8.1'): (60691.02266801026, 1314763.9566447565),
#   (677, 'F8.1'): (103151.41725718141, 267849.5210491015),
#   (1091, 'F8.1'): (10189.823682996728, 161744.28253730256),
#   (1093, 'F8.1'): (1022881.2565320212, 4139187.7236812436),
#   (1094, 'F8.1'): (0.0, 54300.35886651921),
#   (1096, 'F8.1'): (941.2439764767987, 3340.4404577828896),
#   (1097, 'F8.1'): (372239.0956668635, 3594877.5960956207),
#   (1099, 'F8.1'): (7006.043042526656, 9341.390807371521),
#   (1104, 'F8.1'): (9161.718542637882, 20179.771742683362),
#   (1109, 'F8.1'): (18731.812716220767, 87066.23880260464),
#   (1118, 'F8.1'): (125416.44535252833, 137901.91003127504),
#   (1119, 'F8.1'): (54421.66539726706, 1479775.3852602858),
#   (1120, 'F8.1'): (171509.40196073274, 197539.54055870755),
#   (1126, 'F8.1'): (0.0, 139807.34091395303),
#   (1302, 'F8.1'): (234307.4474343388, 240526.26009003143),
#   (1304, 'F8.1'): (99718.87586936822, 126890.7708559212),
#   (1306, 'F8.1'): (20187.35888564334, 82969.82377869348),
#   (1307, 'F8.1'): (0.0, 628663.992300122),
#   (1308, 'F8.1'): (1540.4623009909847, 530086.1802782753),
#   (1312, 'F8.1'): (26215.914577557276, 26215.914577557276),
#   (1313, 'F8.1'): (0.0, 425367.2344424611),
#   (1314, 'F8.1'): (0.0, 66136.75203320374),
#   (1474, 'F8.1'): (49246.53860933126, 69962.12177212426),
#   (1476, 'F8.1'): (1655.0110239898797, 12471.736812570784),
#   (1496, 'F8.1'): (208156.09419911567, 219993.9821968606),
#   (1498, 'F8.1'): (0.0, 796643.0452629747),
#   (1503, 'F8.1'): (806499.1801647879, 2048348.5380227468),
#   (1531, 'F8.1'): (674905.4304964261, 1463934.2080876832),
#   (1534, 'F8.1'): (0.0, 31402.403219867963),
#   (1542, 'F8.1'): (16545.16301047716, 383617.54175568285),
#   (1543, 'F8.1'): (0.0, 379709.86067783774),
#   (1802, 'F8.1'): (0.0, 57372.39464447922),
#   (1936, 'F8.1'): (366322.84320009936, 643593.5420880542),
#   (2199, 'F8.1'): (106.17870784958849, 550.0461460535262),
#   (2298, 'F8.1'): (0.0, 4247.783595079484),
#   (2410, 'F8.1'): (0.0, 50631.02803481256),
#   (2415, 'F8.1'): (76354.84282376793, 234693.19408312324),
#   (2416, 'F8.1'): (43896.5531003236, 127489.42695850224),
#   (2417, 'F8.1'): (921891.896448367, 4711966.74029999),
#   (2434, 'F8.1'): (951754.346299025, 1728864.1486558602),
#   (2438, 'F8.1'): (488673.2458733209, 789807.8421299246),
#   (2439, 'F8.1'): (210610.81211067687, 321324.06336034124),
#   (2446, 'F8.1'): (50856.072410725494, 126747.64873207378),
#   (2447, 'F8.1'): (3880.9357705179227, 118844.86719093015),
#   (2448, 'F8.1'): (797608.1821236663, 1847841.5070407593),
#   (2468, 'F8.1'): (105298.43103091021, 122755.9758511675),
#   (2471, 'F8.1'): (88373.74787383448, 103289.45494509164),
#   (2537, 'F8.1'): (12991.68915967877, 60597.10805397076),
#   (2538, 'F8.1'): (1798.8903220023244, 6682.649661063113),
#   (2570, 'F8.1'): (28748.881533839005, 488028.8158624086),
#   (2571, 'F8.1'): (117325.63215688511, 503894.2426567593),
#   (2572, 'F8.1'): (49760.47457268599, 439024.07753729005),
#   (2573, 'F8.1'): (421919.72499407467, 1062652.788117841),
#   (2574, 'F8.1'): (6705.822440564263, 90645.60430410317),
#   (2575, 'F8.1'): (278309.1615300853, 1447858.2877141698),
#   (2576, 'F8.1'): (3833.066895904997, 84680.8102931888),
#   (2577, 'F8.1'): (113065.72774483857, 1336297.7817271077),
#   (2578, 'F8.1'): (0.0, 248062.74767255955),
#   (2579, 'F8.1'): (11439.156909378036, 246758.04862270423),
#   (2587, 'F8.1'): (0.0, 38759.6840302561),
#   (2589, 'F8.1'): (863655.9306531826, 1481406.5003746552),
#   (2590, 'F8.1'): (386455.3317849151, 1419114.2099530227),
#   (2592, 'F8.1'): (76481.04638957515, 139915.72115018542),
#   (2593, 'F8.1'): (11817.863413952287, 55833.038045675974),
#   (2595, 'F8.1'): (93870.8087584511, 123121.45069378553),
#   (2597, 'F8.1'): (0.0, 366.58757956724304),
#   (2783, 'F8.1'): (870.866914161132, 15634.32104023129),
#   (2788, 'F8.1'): (4618311.43155868, 4621840.321706883),
#   (2790, 'F8.1'): (0.0, 118171.94039014728),
#   (2792, 'F8.1'): (0.0, 15275.146008004154),
#   (2794, 'F8.1'): (0.0, 2282.5769458836667),
#   (2796, 'F8.1'): (0.0, 375396.4008512626),
#   (2797, 'F8.1'): (92248.78507827266, 92248.78507827266),
#   (2798, 'F8.1'): (86001.30223349865, 86001.30223349865),
#   (2799, 'F8.1'): (533525.2119029898, 821148.2208147224),
#   (2800, 'F8.1'): (474277.1573208152, 735302.421337976),
#   (2838, 'F8.1'): (440643.70877602685, 1276331.6984455239),
#   (2839, 'F8.1'): (982908.8441022526, 1132836.27129891),
#   (2840, 'F8.1'): (841841.2052482524, 977243.8541456027),
#   (2841, 'F8.1'): (0.0, 150659.20607578472),
#   (2842, 'F8.1'): (107693.5431601877, 213151.0878757317),
#   (3179, 'F8.1'): (1259.9172014989865, 4527.925830806026),
#   (3180, 'F8.1'): (0.0, 4703.014582130353)},
#  'flood_DERP_RW_M_4326_2080418880': {(162, 'F8.1'): (29505.79512997198,
#    128926.26620015044),
#   (909, 'F8.1'): (45758.78128910145, 47607.55214011745),
#   (910, 'F8.1'): (119100.72929966675, 119100.72929966675),
#   (1253, 'F8.1'): (19058.237129320016, 87879.67614849852),
#   (1256, 'F8.1'): (110560.66288786221, 110560.66288786221),
#   (1257, 'F8.1'): (25657.043882301386, 85420.36958192717),
#   (1258, 'F8.1'): (40663.99572947757, 42073.23218454345),
#   (1260, 'F8.1'): (17795.985418844182, 83067.7550149258),
#   (2471, 'F8.1'): (11502.711410984151, 26972.962688398988)}}

# %%
# Define costs for different transport modes
average_train_load_tons = (896+1344+2160+1344+896+896+1344+1512+896+390)/10 # in Tons per train. Source: Kennisinstituut voor Mobiliteitsbeleid. 2023. Cost Figures for Freight Transport – final report
average_train_cost_per_ton_km = (0.014+0.018+0.047+0.045)/4 # in Euros per ton per km. Source: Kennisinstituut voor Mobiliteitsbeleid. 2023. Cost Figures for Freight Transport – final report
average_road_cost_per_ton_km = (0.395+0.375+0.246+0.203+0.138+0.153+0.125+0.103+0.122+0.099)/10 # in Euros per ton per km. Source: Kennisinstituut voor Mobiliteitsbeleid. 2023. Cost Figures for Freight Transport – final report

# %%
# Loop through the event files and calculate the economic impact of each event
disrupted_asset_lengths={}
disrupted_shortest_paths={}
event_impacts={}

for hazard_map, asset_dict in collect_output.items():
    disrupted_assets = [key[0] for key in asset_dict.keys()]
    disrupted_osm_ids = [
        assets.loc[asset_index]['osm_id'] 
        for asset_index in disrupted_assets 
        if asset_index in assets.index and (
            (assets.loc[asset_index]['bridge'] != 'yes') 
            and (assets.loc[asset_index]['tunnel'] != 'yes')
            and (assets.loc[asset_index]['osm_id'] is not None)
            )
        ]
    
    if len(disrupted_osm_ids)==0:
        continue

    disrupted_edges=[]
    
    for u,v,attr in G.edges(data=True):
        if 'osm_id' not in attr: 
            continue
        if attr['bridge']=='yes' or attr['tunnel']=='yes':
            continue
        matching_ids=[osm_id for osm_id in attr['osm_id'].split('; ') if osm_id in disrupted_osm_ids]
        if len(matching_ids)>0:
            disrupted_edges.append((u,v))
            
    print(f'Disrupted edges: {len(disrupted_edges)}')

    # If there are no disrupted edges in the event, move to next event
    if len(disrupted_edges)==0:
        continue
    
   
    disrupted_shortest_paths[hazard_map]=calculate_new_paths(G_v0, shortest_paths, disrupted_edges)

    if disrupted_shortest_paths[hazard_map] == {}: # No disrupted paths, no economic impact
        print(f'No shortest paths disrupted for {hazard_map}. No economic impact.')
        continue


    print('Calculating economic impact...')
    impact=calculate_economic_impact_shortest_paths(G_v, shortest_paths, disrupted_shortest_paths[hazard_map], average_train_load_tons, average_train_cost_per_ton_km, average_road_cost_per_ton_km)
    event_impacts[hazard_map]=impact
    print(hazard_map, impact)
# Out:
# Disrupted edges: 26
# Calculating economic impact...
# flood_DERP_RW_H_4326_2080411370 26137.726234774877
# Disrupted edges: 2
# No shortest paths disrupted for flood_DERP_RW_H_4326_2080416200. No economic impact.
# Disrupted edges: 60
# Calculating economic impact...
# flood_DERP_RW_H_4326_2080416210 175328.86821810505
# Disrupted edges: 10
# No shortest paths disrupted for flood_DERP_RW_H_4326_2080418880. No economic impact.
# Disrupted edges: 162
# Calculating economic impact...
# flood_DERP_RW_L_4326_2080411370 898895.781341135
# Disrupted edges: 6
# No shortest paths disrupted for flood_DERP_RW_L_4326_2080416200. No economic impact.
# Disrupted edges: 282
# Calculating economic impact...
# flood_DERP_RW_L_4326_2080416210 1219252.911255815
# Disrupted edges: 18
# Calculating economic impact...
# flood_DERP_RW_L_4326_2080418880 29984.12645363179
# Disrupted edges: 68
# Calculating economic impact...
# flood_DERP_RW_M_4326_2080411370 253742.34550722892
# Disrupted edges: 6
# No shortest paths disrupted for flood_DERP_RW_M_4326_2080416200. No economic impact.
# Disrupted edges: 160
# Calculating economic impact...
# flood_DERP_RW_M_4326_2080416210 797684.4196544582
# Disrupted edges: 16
# Calculating economic impact...
# flood_DERP_RW_M_4326_2080418880 29984.12645363179

# %%
event_impacts
# Out:
# {'flood_DERP_RW_H_4326_2080410170': 1938451.04084498,
#  'flood_DERP_RW_H_4326_2080410430': 216070390.9168895,
#  'flood_DERP_RW_H_4326_2080410540': 158177.33876078617,
#  'flood_DERP_RW_H_4326_2080410660': 323626.56432379934,
#  'flood_DERP_RW_H_4326_2080411370': 463592.29160749295,
#  'flood_DERP_RW_H_4326_2080416210': 1206534.0223756128,
#  'flood_DERP_RW_H_4326_2080418600': 5626.436802044873,
#  'flood_DERP_RW_H_4326_2080419180': 32800446.900338236,
#  'flood_DERP_RW_H_4326_2080420240': 4539.418849509301,
#  'flood_DERP_RW_H_4326_2080420340': 1757.0804362529066}

# %%
files = [file for file in os.listdir('C:/Data/interim/collected_flood_runs') if file.endswith('.pkl') and file.startswith('overlay')]
basins_list=list(set([int(file.split('.')[0].split('_')[-1]) for file in files]))
basin_dict = {}
for basin in basins_list:
    basin_dict[basin] = {}
    for key in event_impacts.keys():
        if not str(basin) in key:
            continue
        if str(basin) in key:
            basin_dict[basin][key.split('_RW')[-1][0:3]] = event_impacts[key]


for rp in return_period_dict.keys():
    # add rp as a key to all nested dictionaries with 0 as a value if the rp is not already a key
    for basin in basin_dict.keys():
        if rp not in basin_dict[basin].keys():
            basin_dict[basin][rp] = 0

basin_dict
# Out:
# {2080416200: {'_H_': 0, '_M_': 0, '_L_': 0},
#  2080416210: {'_H_': 175328.86821810505,
#   '_L_': 1219252.911255815,
#   '_M_': 797684.4196544582},
#  2080411370: {'_H_': 26137.726234774877,
#   '_L_': 898895.781341135,
#   '_M_': 253742.34550722892},
#  2080418880: {'_L_': 29984.12645363179, '_M_': 29984.12645363179, '_H_': 0}}

# %%
aggregated_df_by_basin = {}
ead_by_ts_by_basin = {}

for basin, damage_dict in basin_dict.items():
    if len(damage_dict) == 0:
        continue

    aggregated_df_by_basin[basin] = pd.DataFrame.from_dict(damage_dict, orient='index', columns=['Total indirect damage'])
    aggregated_df_by_basin[basin]['Return Period'] = [return_periods[index] for index in aggregated_df_by_basin[basin].index]
    probabilities = [[1 / rp for rp in ts] for ts in aggregated_df_by_basin[basin]['Return Period']]
    aggregated_df_by_basin[basin]['Probability'] = probabilities
    dmgs = []

    for ts in range(len(probabilities[0])):    
        dmgs_m = []

        for rp in range(len(probabilities)-1):
            d_rp= probabilities[rp][ts] - probabilities[rp + 1][ts]
            trap_damage_m = 0.5 * (aggregated_df_by_basin[basin]['Total indirect damage'].iloc[rp] + aggregated_df_by_basin[basin]['Total indirect damage'].iloc[rp + 1])
            dmgs_m.append(d_rp * trap_damage_m)
        
        # Add the portion of damages corresponding to the tails of the distribution
        d0_rp = probabilities[-1][ts]
        damage_m0 = max(aggregated_df_by_basin[basin]['Total indirect damage'])
        dmgs_m.append(d0_rp * damage_m0)

        d_end_rp = (1/4)-probabilities[0][ts]
        damage_m_end = 0.5 * min(aggregated_df_by_basin[basin]['Total indirect damage'])

        dmgs_m.append(d_end_rp * damage_m_end)

        dmgs.append((sum(dmgs_m)))
    
    ead_by_ts_by_basin[basin] = pd.DataFrame(dmgs, columns=['Total indirect damage'])

# %%
#plot the EAD for each basin    
from matplotlib import pyplot as plt
for basin, ead_df in ead_by_ts_by_basin.items():
    plt.plot(ead_df, label=basin)

# %%
# Loop through the event files and calculate the economic impact of each event
disrupted_asset_lengths={}
disrupted_shortest_paths={}
event_impacts={}

for event in events:
    # Load the event data
    event_name = event.split('.')[0]
    event_path = interim_data_path / event

    # Overlay assets with hazard map and find disrupted edges
    disrupted_asset_lengths[event_name]=process_hazard_indirect(event_path, assets, geom_dict)
    disrupted_osm_ids=[assets.loc[asset_index]['osm_id'] for asset_index in disrupted_asset_lengths[event_name].keys()]
    disrupted_edges=[]
    
    for u,v,attr in G.edges(data=True):
        if 'osm_id' not in attr: 
            continue
        if attr['bridge']=='yes' or attr['tunnel']=='yes':
            continue
        matching_ids=[osm_id for osm_id in attr['osm_id'].split('; ') if osm_id in disrupted_osm_ids]
        if len(matching_ids)>0:
            disrupted_edges.append((u,v))
            
    print(f'Disrupted edges: {len(disrupted_edges)}')

    # If there are no disrupted edges in the event, move to next event
    if len(disrupted_edges)==0:
        continue
    
   
    disrupted_shortest_paths[event_name]=calculate_new_paths(G_v0, shortest_paths, disrupted_edges)

    if disrupted_shortest_paths[event_name] == {}: # No disrupted paths, no economic impact
        print(f'No shortest paths disrupted for {event_name}. No economic impact.')
        continue


    print('Calculating economic impact...')
    impact=calculate_economic_impact_shortest_paths(G_v, shortest_paths, disrupted_shortest_paths[event_name], average_train_load_tons, average_train_cost_per_ton_km, average_road_cost_per_ton_km)
    return_period=event_df[event_df['ID']==int(event_name.split('_')[1])]['Return period'].values[0]
    event_impacts[event_name, return_period]=impact
    print(event_name, impact)
# Out:
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28000_DE_1950_River.shp
# 2024-06-03 07:47:53 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28001_DE_1950_River.shp
# 2024-06-03 07:47:54 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28002_DE_1950_River.shp
# 2024-06-03 07:47:54 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28007_DE_1950_River.shp
# 2024-06-03 07:47:54 - Coarse overlay of hazard map with assets...
# Disrupted edges: 16
# No shortest paths disrupted for Event_28007_DE_1950_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28008_DE_1951_River.shp
# 2024-06-03 07:47:56 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28009_DE_1951_River.shp
# 2024-06-03 07:47:57 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28011_DE_1951_River.shp
# 2024-06-03 07:47:57 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28012_DE_1951_River.shp
# 2024-06-03 07:47:58 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28013_DE_1951_River.shp
# 2024-06-03 07:47:58 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28016_DE_1952_River.shp
# 2024-06-03 07:47:58 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28019_DE_1952_River.shp
# 2024-06-03 07:47:59 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28020_DE_1952_River.shp
# 2024-06-03 07:47:59 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28022_DE_1952_River.shp
# 2024-06-03 07:47:59 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28024_DE_1952_River.shp
# 2024-06-03 07:47:59 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28025_DE_1953_River.shp
# 2024-06-03 07:48:00 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28026_DE_1953_River.shp
# 2024-06-03 07:48:00 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28027_DE_1953_River.shp
# 2024-06-03 07:48:00 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28029_DE_1953_River.shp
# 2024-06-03 07:48:01 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28030_DE_1953_River.shp
# 2024-06-03 07:48:01 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28033_DE_1954_River.shp
# 2024-06-03 07:48:05 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28034_DE_1954_River.shp
# 2024-06-03 07:48:08 - Coarse overlay of hazard map with assets...
# Disrupted edges: 236
# Calculating economic impact...
# Event_28034_DE_1954_River 29453063.965048492
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28036_DE_1954_River.shp
# 2024-06-03 07:48:08 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28041_DE_1955_River.shp
# 2024-06-03 07:48:10 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1342
# Calculating economic impact...
# Event_28041_DE_1955_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28043_DE_1955_River.shp
# 2024-06-03 07:48:27 - Coarse overlay of hazard map with assets...
# Disrupted edges: 248
# Calculating economic impact...
# Event_28043_DE_1955_River 37588376.79036642
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28046_DE_1955_River.shp
# 2024-06-03 07:48:30 - Coarse overlay of hazard map with assets...
# Disrupted edges: 204
# Calculating economic impact...
# Event_28046_DE_1955_River 37588376.79036642
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28047_DE_1955_River.shp
# 2024-06-03 07:48:30 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28048_DE_1955_River.shp
# 2024-06-03 07:48:30 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28049_DE_1955_River.shp
# 2024-06-03 07:48:30 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28050_DE_1956_River.shp
# 2024-06-03 07:48:30 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28051_DE_1956_River.shp
# 2024-06-03 07:48:39 - Coarse overlay of hazard map with assets...
# Disrupted edges: 340
# Calculating economic impact...
# Event_28051_DE_1956_River 31691899.868974373
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28057_DE_1956_River.shp
# 2024-06-03 07:48:44 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28058_DE_1956_River.shp
# 2024-06-03 07:48:45 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28059_DE_1956_River.shp
# 2024-06-03 07:48:45 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28060_DE_1956_River.shp
# 2024-06-03 07:48:45 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28062_DE_1956_River.shp
# 2024-06-03 07:48:46 - Coarse overlay of hazard map with assets...
# Disrupted edges: 244
# No shortest paths disrupted for Event_28062_DE_1956_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28064_DE_1957_River.shp
# 2024-06-03 07:48:47 - Coarse overlay of hazard map with assets...
# Disrupted edges: 994
# Calculating economic impact...
# Event_28064_DE_1957_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28065_DE_1957_River.shp
# 2024-06-03 07:48:59 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28067_DE_1957_River.shp
# 2024-06-03 07:48:59 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28068_DE_1957_River.shp
# 2024-06-03 07:49:00 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28073_DE_1958_River.shp
# 2024-06-03 07:49:00 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28074_DE_1958_River.shp
# 2024-06-03 07:49:04 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1246
# Calculating economic impact...
# Event_28074_DE_1958_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28076_DE_1958_River.shp
# 2024-06-03 07:49:47 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28077_DE_1958_River.shp
# 2024-06-03 07:49:49 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28078_DE_1958_River.shp
# 2024-06-03 07:49:49 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28079_DE_1958_River.shp
# 2024-06-03 07:49:49 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28081_DE_1959_River.shp
# 2024-06-03 07:49:51 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28084_DE_1959_River.shp
# 2024-06-03 07:49:52 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28085_DE_1959_River.shp
# 2024-06-03 07:49:53 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28086_DE_1959_River.shp
# 2024-06-03 07:49:53 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28087_DE_1959_River.shp
# 2024-06-03 07:49:55 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28089_DE_1960_River.shp
# 2024-06-03 07:49:55 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28090_DE_1960_River.shp
# 2024-06-03 07:49:56 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28091_DE_1960_River.shp
# 2024-06-03 07:49:56 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28094_DE_1960_River.shp
# 2024-06-03 07:49:56 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28095_DE_1960_River.shp
# 2024-06-03 07:49:57 - Coarse overlay of hazard map with assets...
# Disrupted edges: 272
# No shortest paths disrupted for Event_28095_DE_1960_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28097_DE_1960_River.shp
# 2024-06-03 07:50:02 - Coarse overlay of hazard map with assets...
# Disrupted edges: 386
# Calculating economic impact...
# Event_28097_DE_1960_River 31691899.868974373
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28098_DE_1961_River.shp
# 2024-06-03 07:50:05 - Coarse overlay of hazard map with assets...
# Disrupted edges: 798
# Calculating economic impact...
# Event_28098_DE_1961_River 42638031.00053089
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28101_DE_1961_River.shp
# 2024-06-03 07:50:10 - Coarse overlay of hazard map with assets...
# Disrupted edges: 868
# Calculating economic impact...
# Event_28101_DE_1961_River 42638031.00053089
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28102_DE_1961_River.shp
# 2024-06-03 07:50:12 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28103_DE_1961_River.shp
# 2024-06-03 07:50:12 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28104_DE_1961_River.shp
# 2024-06-03 07:50:15 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28106_DE_1962_River.shp
# 2024-06-03 07:50:15 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28107_DE_1962_River.shp
# 2024-06-03 07:50:15 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28108_DE_1962_River.shp
# 2024-06-03 07:50:16 - Coarse overlay of hazard map with assets...
# Disrupted edges: 24
# No shortest paths disrupted for Event_28108_DE_1962_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28113_DE_1962_River.shp
# 2024-06-03 07:50:16 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28114_DE_1962_River.shp
# 2024-06-03 07:50:16 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28116_DE_1963_River.shp
# 2024-06-03 07:50:19 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28117_DE_1963_River.shp
# 2024-06-03 07:50:19 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28120_DE_1963_River.shp
# 2024-06-03 07:50:19 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28125_DE_1963_River.shp
# 2024-06-03 07:50:22 - Coarse overlay of hazard map with assets...
# Disrupted edges: 24
# No shortest paths disrupted for Event_28125_DE_1963_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28129_DE_1964_River.shp
# 2024-06-03 07:50:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28130_DE_1964_River.shp
# 2024-06-03 07:50:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 16
# No shortest paths disrupted for Event_28130_DE_1964_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28132_DE_1965_River.shp
# 2024-06-03 07:50:25 - Coarse overlay of hazard map with assets...
# Disrupted edges: 26
# Calculating economic impact...
# Event_28132_DE_1965_River 37588376.79036642
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28134_DE_1965_River.shp
# 2024-06-03 07:50:27 - Coarse overlay of hazard map with assets...
# Disrupted edges: 132
# Calculating economic impact...
# Event_28134_DE_1965_River 2810818.30623859
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28135_DE_1965_River.shp
# 2024-06-03 07:50:53 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1010
# Calculating economic impact...
# Event_28135_DE_1965_River 42638031.00053089
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28136_DE_1965_River.shp
# 2024-06-03 07:51:14 - Coarse overlay of hazard map with assets...
# Disrupted edges: 192
# Calculating economic impact...
# Event_28136_DE_1965_River 29453063.965048492
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28137_DE_1965_River.shp
# 2024-06-03 07:51:15 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28138_DE_1965_River.shp
# 2024-06-03 07:51:15 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28139_DE_1965_River.shp
# 2024-06-03 07:51:16 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28140_DE_1965_River.shp
# 2024-06-03 07:51:22 - Coarse overlay of hazard map with assets...
# Disrupted edges: 810
# Calculating economic impact...
# Event_28140_DE_1965_River 42638031.00053089
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28141_DE_1966_River.shp
# 2024-06-03 07:51:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28142_DE_1966_River.shp
# 2024-06-03 07:51:27 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28145_DE_1966_River.shp
# 2024-06-03 07:51:27 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28146_DE_1966_River.shp
# 2024-06-03 07:51:27 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28147_DE_1966_River.shp
# 2024-06-03 07:51:27 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28148_DE_1966_River.shp
# 2024-06-03 07:51:33 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28149_DE_1966_River.shp
# 2024-06-03 07:51:34 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28151_DE_1966_River.shp
# 2024-06-03 07:51:34 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28152_DE_1966_River.shp
# 2024-06-03 07:51:35 - Coarse overlay of hazard map with assets...
# Disrupted edges: 412
# Calculating economic impact...
# Event_28152_DE_1966_River 42638031.00053089
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28155_DE_1966_River.shp
# 2024-06-03 07:51:42 - Coarse overlay of hazard map with assets...
# Disrupted edges: 842
# Calculating economic impact...
# Event_28155_DE_1966_River 42638031.00053089
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28157_DE_1967_River.shp
# 2024-06-03 07:51:44 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28158_DE_1967_River.shp
# 2024-06-03 07:51:45 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28163_DE_1967_River.shp
# 2024-06-03 07:51:46 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28164_DE_1967_River.shp
# 2024-06-03 07:51:49 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28165_DE_1967_River.shp
# 2024-06-03 07:51:49 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28167_DE_1967_River.shp
# 2024-06-03 07:51:49 - Coarse overlay of hazard map with assets...
# Disrupted edges: 226
# Calculating economic impact...
# Event_28167_DE_1967_River 29453063.965048492
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28170_DE_1967_River.shp
# 2024-06-03 07:51:50 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28172_DE_1967_River.shp
# 2024-06-03 07:51:56 - Coarse overlay of hazard map with assets...
# Disrupted edges: 794
# Calculating economic impact...
# Event_28172_DE_1967_River 34502718.17521296
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28173_DE_1968_River.shp
# 2024-06-03 07:51:57 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28174_DE_1968_River.shp
# 2024-06-03 07:52:06 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1160
# Calculating economic impact...
# Event_28174_DE_1968_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28177_DE_1968_River.shp
# 2024-06-03 07:52:10 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28178_DE_1968_River.shp
# 2024-06-03 07:52:10 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28181_DE_1968_River.shp
# 2024-06-03 07:52:11 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28183_DE_1968_River.shp
# 2024-06-03 07:52:11 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28184_DE_1968_River.shp
# 2024-06-03 07:52:15 - Coarse overlay of hazard map with assets...
# Disrupted edges: 434
# Calculating economic impact...
# Event_28184_DE_1968_River 32263882.271287076
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28185_DE_1968_River.shp
# 2024-06-03 07:53:08 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28186_DE_1968_River.shp
# 2024-06-03 07:53:08 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28188_DE_1969_River.shp
# 2024-06-03 07:53:08 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28189_DE_1969_River.shp
# 2024-06-03 07:53:09 - Coarse overlay of hazard map with assets...
# Disrupted edges: 104
# No shortest paths disrupted for Event_28189_DE_1969_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28190_DE_1969_River.shp
# 2024-06-03 07:53:11 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28191_DE_1969_River.shp
# 2024-06-03 07:53:13 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28192_DE_1969_River.shp
# 2024-06-03 07:53:15 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28195_DE_1969_River.shp
# 2024-06-03 07:53:16 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28197_DE_1970_River.shp
# 2024-06-03 07:53:16 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28198_DE_1970_River.shp
# 2024-06-03 07:53:18 - Coarse overlay of hazard map with assets...
# Disrupted edges: 432
# Calculating economic impact...
# Event_28198_DE_1970_River 40192230.61758522
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28199_DE_1970_River.shp
# 2024-06-03 07:53:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1638
# Calculating economic impact...
# Event_28199_DE_1970_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28200_DE_1970_River.shp
# 2024-06-03 07:58:04 - Coarse overlay of hazard map with assets...
# Disrupted edges: 496
# Calculating economic impact...
# Event_28200_DE_1970_River 42638031.00053089
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28201_DE_1970_River.shp
# 2024-06-03 07:58:13 - Coarse overlay of hazard map with assets...
# Disrupted edges: 878
# Calculating economic impact...
# Event_28201_DE_1970_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28203_DE_1970_River.shp
# 2024-06-03 08:00:00 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28204_DE_1970_River.shp
# 2024-06-03 08:00:00 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28205_DE_1970_River.shp
# 2024-06-03 08:00:03 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28206_DE_1970_River.shp
# 2024-06-03 08:00:03 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28208_DE_1970_River.shp
# 2024-06-03 08:00:04 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28209_DE_1971_River.shp
# 2024-06-03 08:00:04 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28211_DE_1971_River.shp
# 2024-06-03 08:00:04 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28212_DE_1971_River.shp
# 2024-06-03 08:00:08 - Coarse overlay of hazard map with assets...
# Disrupted edges: 278
# Calculating economic impact...
# Event_28212_DE_1971_River 29453063.965048492
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28213_DE_1971_River.shp
# 2024-06-03 08:00:09 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28214_DE_1971_River.shp
# 2024-06-03 08:00:09 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28215_DE_1971_River.shp
# 2024-06-03 08:00:09 - Coarse overlay of hazard map with assets...
# Disrupted edges: 106
# No shortest paths disrupted for Event_28215_DE_1971_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28217_DE_1972_River.shp
# 2024-06-03 08:00:13 - Coarse overlay of hazard map with assets...
# Disrupted edges: 176
# Calculating economic impact...
# Event_28217_DE_1972_River 29453063.965048492
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28219_DE_1972_River.shp
# 2024-06-03 08:00:14 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28220_DE_1972_River.shp
# 2024-06-03 08:00:15 - Coarse overlay of hazard map with assets...
# Disrupted edges: 150
# No shortest paths disrupted for Event_28220_DE_1972_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28222_DE_1972_River.shp
# 2024-06-03 08:00:18 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1030
# Calculating economic impact...
# Event_28222_DE_1972_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28225_DE_1973_River.shp
# 2024-06-03 08:00:32 - Coarse overlay of hazard map with assets...
# Disrupted edges: 192
# Calculating economic impact...
# Event_28225_DE_1973_River 2810818.30623859
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28226_DE_1973_River.shp
# 2024-06-03 08:01:00 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28228_DE_1973_River.shp
# 2024-06-03 08:01:01 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28229_DE_1973_River.shp
# 2024-06-03 08:01:01 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28233_DE_1974_River.shp
# 2024-06-03 08:01:01 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28234_DE_1974_River.shp
# 2024-06-03 08:01:03 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28237_DE_1974_River.shp
# 2024-06-03 08:01:05 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28238_DE_1974_River.shp
# 2024-06-03 08:01:16 - Coarse overlay of hazard map with assets...
# Disrupted edges: 308
# Calculating economic impact...
# Event_28238_DE_1974_River 32263882.271287076
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28239_DE_1975_River.shp
# 2024-06-03 08:01:17 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28240_DE_1975_River.shp
# 2024-06-03 08:01:17 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28241_DE_1975_River.shp
# 2024-06-03 08:01:18 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28243_DE_1975_River.shp
# 2024-06-03 08:01:21 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28244_DE_1975_River.shp
# 2024-06-03 08:01:21 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28245_DE_1975_River.shp
# 2024-06-03 08:01:22 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28248_DE_1976_River.shp
# 2024-06-03 08:01:25 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28250_DE_1976_River.shp
# 2024-06-03 08:01:25 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28251_DE_1976_River.shp
# 2024-06-03 08:01:25 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28254_DE_1976_River.shp
# 2024-06-03 08:01:25 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28255_DE_1977_River.shp
# 2024-06-03 08:01:26 - Coarse overlay of hazard map with assets...
# Disrupted edges: 168
# Calculating economic impact...
# Event_28255_DE_1977_River 39800125.405318365
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28256_DE_1977_River.shp
# 2024-06-03 08:01:27 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28257_DE_1977_River.shp
# 2024-06-03 08:01:27 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28258_DE_1977_River.shp
# 2024-06-03 08:01:28 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28259_DE_1977_River.shp
# 2024-06-03 08:01:32 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28260_DE_1977_River.shp
# 2024-06-03 08:01:32 - Coarse overlay of hazard map with assets...
# Disrupted edges: 24
# No shortest paths disrupted for Event_28260_DE_1977_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28261_DE_1977_River.shp
# 2024-06-03 08:01:33 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28263_DE_1978_River.shp
# 2024-06-03 08:01:33 - Coarse overlay of hazard map with assets...
# Disrupted edges: 80
# No shortest paths disrupted for Event_28263_DE_1978_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28264_DE_1978_River.shp
# 2024-06-03 08:01:34 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28265_DE_1978_River.shp
# 2024-06-03 08:01:38 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1072
# Calculating economic impact...
# Event_28265_DE_1978_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28267_DE_1978_River.shp
# 2024-06-03 08:03:10 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28269_DE_1978_River.shp
# 2024-06-03 08:03:16 - Coarse overlay of hazard map with assets...
# Disrupted edges: 692
# Calculating economic impact...
# Event_28269_DE_1978_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28270_DE_1978_River.shp
# 2024-06-03 08:06:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28272_DE_1978_River.shp
# 2024-06-03 08:06:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28273_DE_1978_River.shp
# 2024-06-03 08:06:25 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28274_DE_1979_River.shp
# 2024-06-03 08:06:26 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28275_DE_1979_River.shp
# 2024-06-03 08:06:37 - Coarse overlay of hazard map with assets...
# Disrupted edges: 614
# Calculating economic impact...
# Event_28275_DE_1979_River 39827212.6942923
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28277_DE_1979_River.shp
# 2024-06-03 08:06:38 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28279_DE_1979_River.shp
# 2024-06-03 08:06:40 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28280_DE_1979_River.shp
# 2024-06-03 08:06:40 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28284_DE_1979_River.shp
# 2024-06-03 08:06:41 - Coarse overlay of hazard map with assets...
# Disrupted edges: 190
# Calculating economic impact...
# Event_28284_DE_1979_River 29453063.965048492
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28285_DE_1979_River.shp
# 2024-06-03 08:06:42 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28286_DE_1979_River.shp
# 2024-06-03 08:06:42 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28287_DE_1979_River.shp
# 2024-06-03 08:06:43 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28288_DE_1979_River.shp
# 2024-06-03 08:06:45 - Coarse overlay of hazard map with assets...
# Disrupted edges: 754
# Calculating economic impact...
# Event_28288_DE_1979_River 42638031.00053089
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28291_DE_1980_River.shp
# 2024-06-03 08:06:54 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1232
# Calculating economic impact...
# Event_28291_DE_1980_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28293_DE_1980_River.shp
# 2024-06-03 08:07:05 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28294_DE_1980_River.shp
# 2024-06-03 08:07:05 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28295_DE_1980_River.shp
# 2024-06-03 08:07:11 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1116
# Calculating economic impact...
# Event_28295_DE_1980_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28297_DE_1980_River.shp
# 2024-06-03 08:07:23 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28298_DE_1980_River.shp
# 2024-06-03 08:07:23 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28299_DE_1980_River.shp
# 2024-06-03 08:07:23 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28301_DE_1980_River.shp
# 2024-06-03 08:07:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28302_DE_1980_River.shp
# 2024-06-03 08:07:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28303_DE_1980_River.shp
# 2024-06-03 08:07:25 - Coarse overlay of hazard map with assets...
# Disrupted edges: 330
# Calculating economic impact...
# Event_28303_DE_1980_River 39827212.6942923
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28304_DE_1981_River.shp
# 2024-06-03 08:07:26 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28306_DE_1981_River.shp
# 2024-06-03 08:07:27 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28307_DE_1981_River.shp
# 2024-06-03 08:07:27 - Coarse overlay of hazard map with assets...
# Disrupted edges: 68
# Calculating economic impact...
# Event_28307_DE_1981_River 37588376.79036642
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28308_DE_1981_River.shp
# 2024-06-03 08:07:37 - Coarse overlay of hazard map with assets...
# Disrupted edges: 646
# Calculating economic impact...
# Event_28308_DE_1981_River 34502718.17521296
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28309_DE_1981_River.shp
# 2024-06-03 08:07:38 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28310_DE_1981_River.shp
# 2024-06-03 08:07:39 - Coarse overlay of hazard map with assets...
# Disrupted edges: 128
# Calculating economic impact...
# Event_28310_DE_1981_River 2810818.30623859
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28311_DE_1981_River.shp
# 2024-06-03 08:07:44 - Coarse overlay of hazard map with assets...
# Disrupted edges: 228
# No shortest paths disrupted for Event_28311_DE_1981_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28313_DE_1981_River.shp
# 2024-06-03 08:07:47 - Coarse overlay of hazard map with assets...
# Disrupted edges: 350
# Calculating economic impact...
# Event_28313_DE_1981_River 39827212.6942923
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28315_DE_1981_River.shp
# 2024-06-03 08:07:53 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28316_DE_1981_River.shp
# 2024-06-03 08:07:54 - Coarse overlay of hazard map with assets...
# Disrupted edges: 64
# No shortest paths disrupted for Event_28316_DE_1981_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28317_DE_1981_River.shp
# 2024-06-03 08:07:54 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28319_DE_1981_River.shp
# 2024-06-03 08:07:56 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28321_DE_1981_River.shp
# 2024-06-03 08:07:58 - Coarse overlay of hazard map with assets...
# Disrupted edges: 670
# Calculating economic impact...
# Event_28321_DE_1981_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28322_DE_1981_River.shp
# 2024-06-03 08:08:26 - Coarse overlay of hazard map with assets...
# Disrupted edges: 70
# Calculating economic impact...
# Event_28322_DE_1981_River 29453063.965048492
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28323_DE_1981_River.shp
# 2024-06-03 08:08:39 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1246
# Calculating economic impact...
# Event_28323_DE_1981_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28324_DE_1982_River.shp
# 2024-06-03 08:08:57 - Coarse overlay of hazard map with assets...
# Disrupted edges: 200
# Calculating economic impact...
# Event_28324_DE_1982_River 37588376.79036642
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28326_DE_1982_River.shp
# 2024-06-03 08:08:57 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28328_DE_1982_River.shp
# 2024-06-03 08:08:57 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28329_DE_1982_River.shp
# 2024-06-03 08:08:58 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28330_DE_1982_River.shp
# 2024-06-03 08:08:59 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28332_DE_1982_River.shp
# 2024-06-03 08:08:59 - Coarse overlay of hazard map with assets...
# Disrupted edges: 174
# No shortest paths disrupted for Event_28332_DE_1982_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28333_DE_1982_River.shp
# 2024-06-03 08:09:01 - Coarse overlay of hazard map with assets...
# Disrupted edges: 980
# Calculating economic impact...
# Event_28333_DE_1982_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28336_DE_1983_River.shp
# 2024-06-03 08:09:35 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28337_DE_1983_River.shp
# 2024-06-03 08:09:35 - Coarse overlay of hazard map with assets...
# Disrupted edges: 186
# Calculating economic impact...
# Event_28337_DE_1983_River 37588376.79036642
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28339_DE_1983_River.shp
# 2024-06-03 08:09:39 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1148
# Calculating economic impact...
# Event_28339_DE_1983_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28340_DE_1983_River.shp
# 2024-06-03 08:11:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1800
# Calculating economic impact...
# Event_28340_DE_1983_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28341_DE_1983_River.shp
# 2024-06-03 08:20:39 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28343_DE_1983_River.shp
# 2024-06-03 08:20:52 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28345_DE_1983_River.shp
# 2024-06-03 08:20:54 - Coarse overlay of hazard map with assets...
# Disrupted edges: 38
# No shortest paths disrupted for Event_28345_DE_1983_River. No economic impact.
# ...
# 2024-06-03 08:45:41 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28775_DE_2012_River.shp
# 2024-06-03 08:45:52 - Coarse overlay of hazard map with assets...
# Disrupted edges: 444
# Calculating economic impact...
# Event_28775_DE_2012_River 31691899.868974373
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28777_DE_2013_River.shp
# 2024-06-03 08:45:55 - Coarse overlay of hazard map with assets...
# Disrupted edges: 330
# Calculating economic impact...
# Event_28777_DE_2013_River 31691899.868974373
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28778_DE_2013_River.shp
# 2024-06-03 08:45:55 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28781_DE_2013_River.shp
# 2024-06-03 08:46:15 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1032
# Calculating economic impact...
# Event_28781_DE_2013_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28782_DE_2013_River.shp
# 2024-06-03 08:47:48 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28785_DE_2013_River.shp
# 2024-06-03 08:47:49 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28786_DE_2013_River.shp
# 2024-06-03 08:47:49 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28787_DE_2013_River.shp
# 2024-06-03 08:47:50 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28788_DE_2013_River.shp
# 2024-06-03 08:47:51 - Coarse overlay of hazard map with assets...
# Disrupted edges: 184
# No shortest paths disrupted for Event_28788_DE_2013_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28797_DE_2014_River.shp
# 2024-06-03 08:47:54 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28801_DE_2014_River.shp
# 2024-06-03 08:47:57 - Coarse overlay of hazard map with assets...
# Disrupted edges: 354
# Calculating economic impact...
# Event_28801_DE_2014_River 31691899.868974373
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28802_DE_2014_River.shp
# 2024-06-03 08:47:59 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28803_DE_2014_River.shp
# 2024-06-03 08:47:59 - Coarse overlay of hazard map with assets...
# Disrupted edges: 180
# Calculating economic impact...
# Event_28803_DE_2014_River 29453063.965048492
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28804_DE_2014_River.shp
# 2024-06-03 08:48:00 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28805_DE_2014_River.shp
# 2024-06-03 08:48:00 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28807_DE_2014_River.shp
# 2024-06-03 08:48:00 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28810_DE_2014_River.shp
# 2024-06-03 08:48:04 - Coarse overlay of hazard map with assets...
# Disrupted edges: 518
# Calculating economic impact...
# Event_28810_DE_2014_River 39827212.6942923
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28811_DE_2015_River.shp
# 2024-06-03 08:48:04 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28812_DE_2015_River.shp
# 2024-06-03 08:48:05 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28813_DE_2015_River.shp
# 2024-06-03 08:48:06 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28815_DE_2015_River.shp
# 2024-06-03 08:48:06 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28816_DE_2015_River.shp
# 2024-06-03 08:48:06 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28817_DE_2015_River.shp
# 2024-06-03 08:48:06 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28819_DE_2015_River.shp
# 2024-06-03 08:48:09 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28820_DE_2015_River.shp
# 2024-06-03 08:48:09 - Coarse overlay of hazard map with assets...
# Disrupted edges: 150
# Calculating economic impact...
# Event_28820_DE_2015_River 29453063.965048492
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28823_DE_2015_River.shp
# 2024-06-03 08:48:10 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28824_DE_2015_River.shp
# 2024-06-03 08:48:12 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28825_DE_2015_River.shp
# 2024-06-03 08:48:13 - Coarse overlay of hazard map with assets...
# Disrupted edges: 40
# No shortest paths disrupted for Event_28825_DE_2015_River. No economic impact.
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28826_DE_2015_River.shp
# 2024-06-03 08:48:13 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28830_DE_2016_River.shp
# 2024-06-03 08:48:14 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28831_DE_2016_River.shp
# 2024-06-03 08:48:18 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28832_DE_2016_River.shp
# 2024-06-03 08:48:18 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28833_DE_2016_River.shp
# 2024-06-03 08:48:21 - Coarse overlay of hazard map with assets...
# Disrupted edges: 234
# Calculating economic impact...
# Event_28833_DE_2016_River 29453063.965048492
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28834_DE_2016_River.shp
# 2024-06-03 08:48:22 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28835_DE_2016_River.shp
# 2024-06-03 08:48:23 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28837_DE_2016_River.shp
# 2024-06-03 08:48:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28840_DE_2016_River.shp
# 2024-06-03 08:48:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28844_DE_2017_River.shp
# 2024-06-03 08:48:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28846_DE_2017_River.shp
# 2024-06-03 08:48:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28847_DE_2017_River.shp
# 2024-06-03 08:48:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28848_DE_2017_River.shp
# 2024-06-03 08:48:24 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28851_DE_2017_River.shp
# 2024-06-03 08:48:28 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28852_DE_2017_River.shp
# 2024-06-03 08:48:33 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28853_DE_2017_River.shp
# 2024-06-03 08:48:34 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28854_DE_2017_River.shp
# 2024-06-03 08:48:35 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28856_DE_2017_River.shp
# 2024-06-03 08:48:36 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28857_DE_2017_River.shp
# 2024-06-03 08:48:36 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28858_DE_2017_River.shp
# 2024-06-03 08:48:37 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28859_DE_2017_River.shp
# 2024-06-03 08:48:44 - Coarse overlay of hazard map with assets...
# Disrupted edges: 1116
# Calculating economic impact...
# Event_28859_DE_2017_River 43003048.9238238
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28861_DE_2018_River.shp
# 2024-06-03 08:49:06 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28862_DE_2018_River.shp
# 2024-06-03 08:49:06 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28864_DE_2018_River.shp
# 2024-06-03 08:49:06 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28865_DE_2018_River.shp
# 2024-06-03 08:49:06 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28866_DE_2018_River.shp
# 2024-06-03 08:49:07 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28867_DE_2018_River.shp
# 2024-06-03 08:49:07 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28870_DE_2018_River.shp
# 2024-06-03 08:49:07 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28873_DE_2018_River.shp
# 2024-06-03 08:49:07 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28875_DE_2018_River.shp
# 2024-06-03 08:49:07 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28877_DE_2019_River.shp
# 2024-06-03 08:49:07 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28878_DE_2019_River.shp
# 2024-06-03 08:49:07 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28879_DE_2019_River.shp
# 2024-06-03 08:49:08 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28882_DE_2019_River.shp
# 2024-06-03 08:49:11 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28884_DE_2019_River.shp
# 2024-06-03 08:49:11 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28885_DE_2019_River.shp
# 2024-06-03 08:49:11 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28886_DE_2019_River.shp
# 2024-06-03 08:49:11 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28888_DE_2019_River.shp
# 2024-06-03 08:49:12 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28889_DE_2019_River.shp
# 2024-06-03 08:49:12 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28890_DE_2020_River.shp
# 2024-06-03 08:49:17 - Coarse overlay of hazard map with assets...
# Disrupted edges: 396
# Calculating economic impact...
# Event_28890_DE_2020_River 31691899.868974373
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28893_DE_2020_River.shp
# 2024-06-03 08:49:18 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28894_DE_2020_River.shp
# 2024-06-03 08:49:18 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28895_DE_2020_River.shp
# 2024-06-03 08:49:18 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28896_DE_2020_River.shp
# 2024-06-03 08:49:20 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28897_DE_2020_River.shp
# 2024-06-03 08:49:20 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28898_DE_2020_River.shp
# 2024-06-03 08:49:21 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0
# Flood map path: C:\Data\interim\event_data_inspection\overlapping_floods_shapefiles\Event_28900_DE_2020_River.shp
# 2024-06-03 08:49:21 - Coarse overlay of hazard map with assets...
# Disrupted edges: 0

# %%
# Create a Series from disrupted shortest paths with the same keys as event_impacts
dspaths_list = pd.Series({key: disrupted_shortest_paths[key[0]] for key in event_impacts.keys()})

# Create a DataFrame from event_impacts
event_impacts_df = pd.DataFrame.from_dict(event_impacts, orient='index', columns=['Economic Impact (EUR)'])

# Concatenate the DataFrame and the Series along the columns axis
event_impacts_df = pd.concat([event_impacts_df, dspaths_list], axis=1)

# Sort the DataFrame
event_impacts_df = event_impacts_df.sort_values(by='Economic Impact (EUR)', ascending=False)



event_impacts_df
# Out:
#                                     Economic Impact (EUR)  \
# (Event_28340_DE_1983_River, 4.03)            4.300305e+07
# (Event_28041_DE_1955_River, 2.86)            4.300305e+07
# (Event_28265_DE_1978_River, 5.62)            4.300305e+07
# (Event_28269_DE_1978_River, 21.01)           4.300305e+07
# (Event_28291_DE_1980_River, 2.15)            4.300305e+07
# ...                                                   ...
# (Event_28566_DE_1999_River, 12.18)           2.810818e+06
# (Event_28134_DE_1965_River, 2.1)             2.810818e+06
# (Event_28371_DE_1986_River, 3.57)            2.810818e+06
# (Event_28523_DE_1996_River, 3.04)            2.810818e+06
# (Event_28507_DE_1995_River, 5.02)            2.810818e+06
#
#                                                                                     0
# (Event_28340_DE_1983_River, 4.03)   {(2661, 2124): ([2661, 1822, 1823, 1817, 1825,...
# (Event_28041_DE_1955_River, 2.86)   {(2661, 2124): ([2661, 1822, 1823, 1817, 1825,...
# (Event_28265_DE_1978_River, 5.62)   {(2661, 2124): ([2661, 1822, 1823, 1817, 1825,...
# (Event_28269_DE_1978_River, 21.01)  {(2661, 2124): ([2661, 1822, 1823, 1817, 1825,...
# (Event_28291_DE_1980_River, 2.15)   {(2661, 2124): ([2661, 1822, 1823, 1817, 1825,...
# ...                                                                               ...
# (Event_28566_DE_1999_River, 12.18)  {(1363, 3071): ([1363, '1363_d', '2765_d', '13...
# (Event_28134_DE_1965_River, 2.1)    {(1363, 3071): ([1363, '1363_d', '2765_d', '13...
# (Event_28371_DE_1986_River, 3.57)   {(1363, 3071): ([1363, '1363_d', '2765_d', '13...
# (Event_28523_DE_1996_River, 3.04)   {(1363, 3071): ([1363, '1363_d', '2765_d', '13...
# (Event_28507_DE_1995_River, 5.02)   {(1363, 3071): ([1363, '1363_d', '2765_d', '13...
#
# [101 rows x 2 columns]

# %%
event_df
# Out:
#            ID Country code  Year    Country name  Start date    End date  \
# 0        2001           AL  1950         Albania  30/10/1950  20/11/1950
# 1        2002           AL  1950         Albania  08/12/1950  26/12/1950
# 2        2003           AL  1951         Albania  20/10/1951  05/11/1951
# 3        2009           AL  1952         Albania  03/12/1952  12/12/1952
# 4        2010           AL  1952         Albania  14/12/1952  24/12/1952
# ...       ...          ...   ...             ...         ...         ...
# 14727  284983           UK  2019  United Kingdom  03/03/2019  23/03/2019
# 14728  284994           UK  2019  United Kingdom  24/09/2019  02/10/2019
# 14729  284997           UK  2020  United Kingdom  06/01/2020  19/01/2020
# 14730  284999           UK  2020  United Kingdom  07/02/2020  16/03/2020
# 14731  285015           UK  2020  United Kingdom  13/12/2020  29/12/2020
#
#            Type                                             Source  \
# 0         River  Aoos;Crni Drim, Drin;Devoll, Shkumbini;Mat;Shk...
# 1         River           Aoos;Crni Drim, Drin;Moraca, Bojana;Osum
# 2         River  Aoos;Crni Drim, Drin;Devoll, Shkumbini;Osum;Sh...
# 3         River  Aoos;Crni Drim, Drin;Devoll, Shkumbini;Mat;Mor...
# 4         River       Beli Drim;Crni Drim, Drin;Mat;Moraca, Bojana
# ...         ...                                                ...
# 14727  Compound  Blackwater, Bann;Derg;Finn;Main;Strule, Mourne...
# 14728  Compound  Avon of Bristol;Avon of Tewkesbury;Brue;Dee or...
# 14729  Compound  Arun;Avon of Bournemouth, Stour of Bournemouth...
# 14730  Compound  Aire;Annalee, Erne;Annan;Arun;Avon of Bournemo...
# 14731  Compound  Exe;Tamar;Taw;Torridge;Bristol Channel;English...
#
#                            Regions affected (NUTS v2010)  \
# 0      AL011;AL012;AL013;AL014;AL021;AL022;AL031;AL03...
# 1                                      AL015;AL033;AL035
# 2                                      AL032;AL034;AL035
# 3              AL011;AL014;AL015;AL031;AL032;AL033;AL035
# 4                                AL011;AL013;AL014;AL015
# ...                                                  ...
# 14727                                        UKM63;UKN04
# 14728    UKJ33;UKK12;UKK13;UKK23;UKL12;UKL14;UKL21;UKL22
# 14729  UKJ24;UKJ33;UKK21;UKK22;UKK43;UKM31;UKM32;UKM6...
# 14730  UKC21;UKD11;UKD12;UKD43;UKD63;UKE12;UKE13;UKE2...
# 14731                                              UKK43
#
#                            Regions affected (NUTS v2021)  ...  \
# 0      AL011;AL012;AL013;AL014;AL021;AL022;AL031;AL03...  ...
# 1                                      AL015;AL033;AL035  ...
# 2                                      AL032;AL034;AL035  ...
# 3              AL011;AL014;AL015;AL031;AL032;AL033;AL035  ...
# 4                                AL011;AL013;AL014;AL015  ...
# ...                                                  ...  ...
# 14727                            UKM63;UKM81;UKN0A;UKN0C  ...
# 14728  UKJ35;UKJ36;UKJ37;UKK12;UKK13;UKK23;UKL12;UKL1...  ...
# 14729  UKJ27;UKJ28;UKJ35;UKJ36;UKJ37;UKK24;UKK25;UKK4...  ...
# 14730  UKC21;UKD11;UKD12;UKD44;UKD45;UKD46;UKD47;UKD6...  ...
# 14731                                              UKK43  ...
#
#        Economic loss, YE  Economic loss, 1950  Economic loss, 2020  \
# 0                  56500                56500              2627311
# 1                  11835                11835               169937
# 2                  24087                19799              1000253
# 3                  39729                31504               644787
# 4                  38272                30534               688512
# ...                  ...                  ...                  ...
# 14727             379593                81661               347892
# 14728           16507953              1911015             15921857
# 14729            6371017               683780              6371017
# 14730           58302734              8421701             58302734
# 14731             799530               105599               799530
#
#        Loss threshold  Mean water depth  Return period  Hydro data  \
# 0               15107              1790           1.99           0
# 1               15107              1451           1.50           0
# 2               15649              1734           2.02           0
# 3               16190              1762           1.28           0
# 4               16190              2657           3.71           0
# ...               ...               ...            ...         ...
# 14727          801774              2283           4.07           1
# 14728          801774              1905           3.00           1
# 14729          720692              2366           6.30           1
# 14730          720692              1963           4.81           1
# 14731          720692              2115           3.04           1
#
#        RP2 exceedance  Category  HANZE ID
# 0                   0         F       NaN
# 1                   0         F       NaN
# 2                   0         F       NaN
# 3                   0         C       NaN
# 4                   0         C       NaN
# ...               ...       ...       ...
# 14727               1         C       NaN
# 14728               1         C       NaN
# 14729               1         C       NaN
# 14730               1         C       NaN
# 14731               1         F       NaN
#
# [14732 rows x 27 columns]

# %%
# Visualisation

def get_node_from_spaths(shortest_paths):
    nodes_list = []
    for key in shortest_paths.keys():
        origin, destination = key
        nodes_list.append(origin)
        nodes_list.append(destination)

    nodes_list = list(set(nodes_list))  # Remove duplicates

    return nodes_list

def from_spaths_to_edges(shortest_paths):
    edges_in_paths = []
    for (o, d), (nodes_in_path, demand) in shortest_paths.items():
        if nodes_in_path is None:
            print(f'No path found between {o} and {d}. Cannot ship by train.')
            continue
        
        edges_in_path = [(nodes_in_path[i], nodes_in_path[i+1]) for i in range(len(nodes_in_path)-1)]
        edges_in_paths.extend(edges_in_path)
    return edges_in_paths

# %%
import contextily as ctx

# Set node positions for virtual nodes

extract_numeric_part = lambda s: int(re.search(r'\d+', s).group()) if re.search(r'\d+', s) else None
for u,attr in G_v.nodes(data=True):
    try:
        if isinstance(u, int): 
            pass
        elif isinstance(u, str): 
            if u == 'source_sink_d':
                attr['pos']=(G.nodes['source_sink']['pos'][0],G_v.nodes['source_sink']['pos'][-1])
            else:
                attr['pos']=(G_v.nodes[extract_numeric_part(u)]['pos'][0],G_v.nodes[extract_numeric_part(u)]['pos'][-1])
    except:
        print(f'Error in setting node {u} position')  

pos=nx.get_node_attributes(G_v, 'pos')

# Define edge list, od list(node list), node size, and edge width
od_list = get_node_from_spaths(shortest_paths)
edgelist=[(u, v) for u, v in G.edges(data=False) if (type(u) == int and type(v) == int)]
node_size=[int(abs(ceil(attr['demand']/10))+1) for u, attr in G.nodes(data=True) if 'demand' in attr and attr['demand'] != 0]
width=[G[u][v][0]['capacity'] for u, v in edgelist]
spaths_list = from_spaths_to_edges(shortest_paths)



for e in event_impacts_df.index:
    if e[0]!='Event_28200_DE_1970_River':continue
    
    fig, ax = plt.subplots()
    event_name = e[0]
    event_disrupted_spathedges = from_spaths_to_edges(disrupted_shortest_paths[event_name])

    nx.draw_networkx(G, pos,
            nodelist=od_list,
            edgelist=edgelist,
            with_labels=False,
            arrows=False,
            node_size=10,
            node_color='green',
            width=width,
            edge_color='grey',
            ax=ax)


    # Draw the shortest paths
    nx.draw_networkx_edges(G, pos, edgelist=spaths_list, edge_color='cyan', width=1, arrows=False, ax=ax)
#    # Draw the disrupted edges
    nx.draw_networkx_edges(G_v, pos, edgelist=event_disrupted_spathedges, 
                           edge_color=['red' if '_d' in str(u) or '_d' in str(v) else 'green' for (u,v) in event_disrupted_spathedges],
                           style='--', width=2, arrows=False, ax=ax)
    

    # Load the hazard footprint data
    hazard_data = gpd.read_file(interim_data_path / (str(e[0])+'.shp')).to_crs(3857)

    # Plot the hazard footprint
    hazard_data.plot(ax=ax, color='blue')
            
    # Add the basemap
    ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik, zoom_adjust=1)

    # Set the axis limits
    ax.set_xlim([bbox_shape.bounds[0], bbox_shape.bounds[1]])
    ax.set_ylim([bbox_shape.bounds[2], bbox_shape.bounds[3]])

    # Show the plot
    plt.show()
    sleep(1)
    clear_output(wait=True)
# Out:
# C:\Users\peregrin\AppData\Local\Temp\ipykernel_29432\2725870815.py:51: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   nx.draw_networkx_edges(G_v, pos, edgelist=event_disrupted_spathedges,

# %%
disruptions_df.sort_values(by='event_cost', ascending=False)

# %%
import matplotlib.pyplot as plt

# Create a figure and subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
df=disruptions_df[disruptions_df['event_name']!='Event_28000_DE_1950_River']
# Plot 1: Cost vs Return Period
axs[0, 0].scatter(df['rp'], df['event_cost'])
axs[0, 0].set_xlabel('Return Period')
axs[0, 0].set_ylabel('Cost')

# Plot 2: Cost vs Number of Assets
axs[0, 1].scatter(df['num_disrupted_assets'], df['event_cost'])
axs[0, 1].set_xlabel('Number of Assets')
axs[0, 1].set_ylabel('Cost')

# Plot 3: Cost vs Total Length of Disrupted Assets
axs[1, 0].scatter(df['total_disrupted_length'], df['event_cost'])
axs[1, 0].set_xlabel('Total Length of Disrupted Assets')
axs[1, 0].set_ylabel('Cost')

# Plot 4: Total Length of Disrupted Assets vs Number of Assets
axs[1, 1].scatter(df['num_disrupted_assets'], df['total_disrupted_length'])
axs[1, 1].set_xlabel('Number of Assets')
axs[1, 1].set_ylabel('Total Length of Disrupted Assets')

# Adjust spacing between subplots and show the plot
plt.tight_layout()
plt.show()

# %%
# disrupted_asset_lengths['Event_28000_DE_1950_River'][4829]

# %%
import geopandas as gpd
import lonboard as lb

name1='Event_28051_DE_1956_River'
name2='Event_28074_DE_1958_River'

# Load the GeoDataFrames
gdf1 = gpd.read_file(interim_data_path / (name1 + '.shp'))
gdf2 = gpd.read_file(interim_data_path / (name2 + '.shp'))

# lb.viz(gdf1)


layer1 = lb.PathLayer.from_geopandas(gpd.read_file(assets_path), width_min_pixels=0.8)

# %%
layer2 = lb.PolygonLayer.from_geopandas(
    gdf2,
    get_line_width=20,  # width in default units (meters)
    line_width_min_pixels=0.2,  # minimum width when zoomed out
    get_fill_color=[204, 251, 254],  # light blue
    get_line_color=[120, 120, 120],  # dark border color
)
map_ = lb.Map([layer1, layer2])
map_
# Out:
# c:\Users\peregrin\AppData\Local\anaconda3\envs\ci_adapt_env\Lib\site-packages\lonboard\_geoarrow\ops\reproject.py:97: UserWarning: Input being reprojected to EPSG:4326 CRS
#   warnings.warn("Input being reprojected to EPSG:4326 CRS")
# Map(layers=[PathLayer(table=pyarrow.Table
# osm_id: string
# railway: string
# name: string
# gauge: string
# electrifie…

# %%
#TODO: remove after testing is finalised
max_flow = 0
for origin, destinations in flow_dict.items():
    for destination, flow in destinations.items():
        max_flow = max(max_flow, max(flow.values()))
        if len(list(flow.keys())) > 1: 
            if (flow[0] > 0) and (flow[1] > 0):
                print(f'WARNING: multiple flows from {origin} to {destination}: {flow}')
        if flow[0] > 0:
            print(f"Origin: {origin} Destination: {destination} Flow: {flow[0]}")
            if origin == 'source_sink' or destination == 'source_sink':
                print("^^^SOURCE_SINK FLOW^^^")

print('Max flow: '+str(max_flow))

# %%
n_sourcesink=0
n_notsourcesink=0
for u,v in G.edges(data=False):
    if not 'source_sink'in str(u) and not 'source_sink' in str(v):
        n_notsourcesink+=1
        if not (type(u)==int and type(v)==int):
            print(u,v)
    else:    
        n_sourcesink+=1     

print(f'Number of source_sink edges: {n_sourcesink}')
print(f'Number of not source_sink edges: {n_notsourcesink}')

# %%
# Initialize a list to store rows
rows = []

# Iterate over the edges and add rows to the list
for i, (origin, destination, attributes) in enumerate(G_v.edges(data=True)):
    # Create a new row with the index, origin, and destination
    row = {'origin': origin, 'destination': destination}
    
    # Add each attribute as a new column
    for key, value in attributes.items():
        row['flow'] = flow_dict[origin][destination][0]
        row['disrupted_flow'] = mcf[origin][destination][0]
        row[key] = value
        
    

    # Append the row to the list
    rows.append(row)

# Convert the list of rows to a DataFrame
edges_df = pd.DataFrame(rows)
edges_df[edges_df['flow'] != edges_df['disrupted_flow']].sort_values(by='disrupted_flow', ascending=False).head(5)

# %%
def delta_flow_analysis(delta_flow,event_name):
    source_sink_increase=[] # These are the flows that increase to or from the source_sink node. Highest cost nodes so only activated if the node is disconnected
    source_sink_decrease=[] # These are the flows that decrease to or from the source_sink node. 
    real_edges_increase=[] # Increase in flow on previously unsaturated edge 
    real_edges_decrease=[] # Decrease in flow 
    dummy_edges_increase=[] # Increase in flow on dummy edges if exceeding capacity
    dummy_edges_decrease=[] # Decrease in flow on dummy edges
    overflow_edges_increase=[] # Increase in flow on mixed edges 
    overflow_edges_decrease=[] # Decrease in flow on mixed edges
    for (event_name, (u,v)), d_flow in delta_flow.items():
        if 'source_sink' in str(u) or 'source_sink' in str(v):
            if d_flow > 0:
                source_sink_increase.append(((u,v),d_flow))
            if d_flow < 0:
                source_sink_decrease.append(((u,v),d_flow))
            continue
        if type(u)==int and type(v)==int:
            if d_flow > 0:
                real_edges_increase.append(((u,v),d_flow))
            if d_flow < 0:  
                real_edges_decrease.append(((u,v),d_flow))
            continue
        if str(u).split('_')[-1] == 'd' and str(v).split('_')[-1] == 'd':
            if d_flow > 0:
                dummy_edges_increase.append(((u,v),d_flow))
            if d_flow < 0:  
                dummy_edges_decrease.append(((u,v),d_flow))
            continue
        if str(u).split('_')[-1] == 'd' or str(v).split('_')[-1] == 'd':
            if d_flow > 0:
                overflow_edges_increase.append(((u,v),d_flow))
            if d_flow < 0:  
                overflow_edges_decrease.append(((u,v),d_flow))
            continue
        else:
            print(f'Error in {u,v}',end=' ')
    print(f'\n\nIncrease in flow to source_sink: {len(source_sink_increase)}')
    print(f'Decrease in flow to source_sink: {len(source_sink_decrease)}')
    print(f'Increase in flow on real edges: {len(real_edges_increase)}')
    print(f'Decrease in flow on real edges: {len(real_edges_decrease)}')
    print(f'Increase in flow on dummy edges: {len(dummy_edges_increase)}')
    print(f'Decrease in flow on dummy edges: {len(dummy_edges_decrease)}')
    print(f'Increase in flow on overflow edges: {len(overflow_edges_increase)}')
    print(f'Decrease in flow on overflow edges: {len(overflow_edges_decrease)}\n\n')
    return source_sink_increase, source_sink_decrease, real_edges_increase, real_edges_decrease, dummy_edges_increase, dummy_edges_decrease, overflow_edges_increase, overflow_edges_decrease
