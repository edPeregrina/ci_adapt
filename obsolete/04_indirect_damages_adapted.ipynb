# %% [markdown]
# This notebook calculates the change in direct damage to specified assets

# %%
# Imports
import configparser
from pathlib import Path
import pathlib
from direct_damages import damagescanner_rail_track as ds
import pandas as pd
import geopandas as gpd
# import datetime
from ci_adapt_utilities import *
import pickle

# %%
# Load configuration with ini file (created running config.py)
config_file=r'C:\repos\ci_adapt\config_ci_adapt.ini'
config = configparser.ConfigParser()
config.read(config_file)

p = Path('..')
hazard_type = config.get('DEFAULT', 'hazard_type')
infra_type = config.get('DEFAULT', 'infra_type')
country_code = config.get('DEFAULT', 'country_code')
country_name = config.get('DEFAULT', 'country_name')
hazard_data_subfolders = config.get('DEFAULT', 'hazard_data_subfolders')
asset_data = config.get('DEFAULT', 'asset_data')
vulnerability_data = config.get('DEFAULT', 'vulnerability_data')
data_path = Path(pathlib.Path.home().parts[0]) / 'Data'
interim_data_path = data_path / 'interim' / 'collected_flood_runs'

# %%
# Read exposure data (OSM, OpenStreetMap contributors (2024) / osm-flex)
assets_path = data_path / asset_data
assets = gpd.read_file(assets_path)
assets = gpd.GeoDataFrame(assets).set_crs(4326).to_crs(3857)
assets = assets.loc[assets.geometry.geom_type == 'LineString']
assets = assets.rename(columns={'railway' : 'asset'})

# # Drop bridges and tunnels
# assets = assets.loc[~(assets['bridge'].isin(['yes']))]
# assets = assets.loc[~(assets['tunnel'].isin(['yes']))]

assets = assets[assets['railway:traffic_mode']!='"passenger"']
assets = assets.reset_index(drop=True)

# Add buffer to assets to do area intersect and create dictionaries for quicker lookup
buffered_assets = ds.buffer_assets(assets)
geom_dict = assets['geometry'].to_dict()
type_dict = assets['asset'].to_dict()

print(f"{len(assets)} assets loaded.")

# Read vulnerability and maximum damage data from Nirandjan, S., et al. (2024)
curve_types = {'rail': ['F8.1']}
infra_curves, maxdams = ds.read_vul_maxdam(data_path, hazard_type, infra_type)
max_damage_tables = pd.read_excel(data_path / vulnerability_data / 'Table_D3_Costs_V1.0.0.xlsx',sheet_name='Cost_Database',index_col=[0])
print(f'Found matching infrastructure curves for: {infra_type}')
# Out:
# 3187 assets loaded.
# Found matching infrastructure curves for: rail

# %%
# open pickled hazard-asset overlay and hazard intensity data
with open(interim_data_path / 'overlay_assets_flood_DERP_RW_L_4326_2080411370.pkl', 'rb') as f:
    overlay_assets = pickle.load(f)
with open(interim_data_path / 'hazard_numpified_flood_DERP_RW_L_4326_2080411370.pkl', 'rb') as f:
    hazard_numpified_list = pickle.load(f)

# %%
# Set up the path
adapt_path = Path(r'C:\Data\interim\adaptations\test_haz_level_adapt.geojson')

# Load the polygon of the protected area
protected_area = gpd.read_file(adapt_path).to_crs(3857)

# Filter assets that are within the protected area
filtered_assets = gpd.overlay(assets, protected_area, how='intersection')
f_assets = assets.loc[(assets['osm_id'].isin(filtered_assets['osm_id']))]
f_assets.head(3)
# assets = assets.loc[~(assets['bridge'].isin(['yes']))]
# Out:
#        osm_id asset                 name gauge   electrified voltage bridge  \
# 37    7990468  rail                 None  1435  contact_line   15000   None
# 313  33506714  rail  Rechte Rheinstrecke  1435  contact_line   15000    yes
# 314  33506715  rail  Rechte Rheinstrecke  1435  contact_line   15000   None
#
#     maxspeed service tunnel  \
# 37       120    None   None
# 313      100    None   None
# 314      100    None   None
#
#                                             other_tags railway:traffic_mode  \
# 37   "frequency"=>"16.7","operator"=>"DB Netz AG","...              "mixed"
# 313  "frequency"=>"16.7","layer"=>"1","operator"=>"...              "mixed"
# 314  "embankment"=>"yes","frequency"=>"16.7","opera...              "mixed"
#
#       usage                                           geometry  \
# 37   "main"  LINESTRING (810131.824 6545141.628, 810131.034...
# 313  "main"  LINESTRING (806342.732 6547553.449, 806364.083...
# 314  "main"  LINESTRING (806681.210 6547474.401, 806676.935...
#
#                                               buffered
# 37   POLYGON ((810131.0332578894 6545143.573510949,...
# 313  POLYGON ((806364.0829647976 6547544.350868201,...
# 314  POLYGON ((806676.934860112 6547474.821351372, ...

# %%
# optionally to calculate the maximum intensity for each hazard point, this can be used, else a float can be used
max_intensity = []

for asset_id in f_assets.index:
    max_intensity.append(retrieve_max_intensity_by_asset(asset_id, overlay_assets, hazard_numpified_list))

# %%
retrieve_max_intensity_by_asset(asset_id, overlay_assets, hazard_numpified_list)
# Out:
# array([4.0, 4.0], dtype=object)

# %%
overlay_assets
#f_assets
#asset_id
# Out:
#      asset  hazard_point
# 0       37             5
# 1       37            10
# 2       37             8
# 3      269             1
# 4      269             8
# ..     ...           ...
# 217   2725             5
# 218   2726             3
# 219   2726             5
# 220   3004             9
# 221   3004             8
#
# [222 rows x 2 columns]

# %%
# extract the assets that will be adapted
changed_assets = f_assets # testing with a few assets
# add new columns fragility_mod and haz_mod
changed_assets['fragility_mod'] = 1 #[0.3, 0.5, 0.8] #fraction [example considering no reduction] (1 = no reduction, 0 = invulnerable asset) DUMMY DATA FOR TESTING
# changed_assets['haz_mod'] = [np.max(x) for x in max_intensity] #meters [example adding wall of maximum flooding depth + 1 meter] (0 = no reduction in hazard intensity, 0.5 = 0.5 meter reduction in hazard intensity) DUMMY DATA FOR TESTING consider raising railway 0.5 meters
changed_assets['haz_mod'] = [np.max(x) if len(x) > 0 else 0 for x in max_intensity]

# TODO: automate infrastructure curve deduction from dictionary keys, now running with curve F8.1
hazard_intensity = infra_curves['F8.1'].index.values
fragility_values = (np.nan_to_num(infra_curves['F8.1'].values,nan=(np.nanmax(infra_curves['F8.1'].values)))).flatten()
maxdams_filt=max_damage_tables[max_damage_tables['ID number']=='F8.1']['Amount']

adaptation_run = run_damage_reduction_by_asset(geom_dict, overlay_assets, hazard_numpified_list, changed_assets, hazard_intensity, fragility_values, maxdams_filt)

#reporting
for asset_id, baseline_damages in adaptation_run[0].items():
    print(f'\nADAPTATION results for asset {asset_id}:')
    print(f'Baseline damages for asset {asset_id}: {baseline_damages[0]:.2f} to {baseline_damages[1]:.2f} EUR')
    print(f'Adapted damages for asset {asset_id}: {adaptation_run[1][asset_id][0]:.2f} to {adaptation_run[1][asset_id][1]:.2f} EUR')
    delta = tuple(adaptation_run[1][asset_id][i] - baseline_damages[i] for i in range(len(baseline_damages)))
    # percent_change = tuple((100 * (delta[i] / baseline_damages[i])) for i in range(len(baseline_damages)))
    percent_change = tuple((100 * (delta[i] / baseline_damages[i])) if baseline_damages[i] != 0 else 0 for i in range(len(baseline_damages)))
    print(f'Change (Adapted-Baseline): {delta[0]:.2f} to {delta[1]:.2f} EUR, {percent_change}% change, at a cost of {adaptation_run[2][asset_id]:.2f} EUR')

#TODO Check with economist: ammortization of adaptation cost over years of adaptation scenario
    #NEXT: adaptation_run returns (collect_inb_bl, collect_inb_adapt, adaptation_cost). These can be used to calculate the EAD for the adapted scenario (and damage reduction), and compare with the adaptation cost, which must be ammortized over the years of the adaptation scenario.
# Out:
# c:\Users\peregrin\AppData\Local\anaconda3\envs\ci_adapt_env\Lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# c:\Users\peregrin\AppData\Local\anaconda3\envs\ci_adapt_env\Lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# 2024-07-19 13:32:59 - Calculating adapted damages for assets...
# 100%|██████████| 98/98 [01:17<00:00,  1.26it/s]
# 33 assets with no change.
#
# ADAPTATION results for asset 37:
# Baseline damages for asset 37: 543666.18 to 2458653.92 EUR
# Adapted damages for asset 37: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -543666.18 to -2458653.92 EUR, (-100.0, -100.0)% change, at a cost of 22101136.68 EUR
#
# ADAPTATION results for asset 314:
# Baseline damages for asset 314: 0.00 to 112136.25 EUR
# Adapted damages for asset 314: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): 0.00 to -112136.25 EUR, (0, -100.0)% change, at a cost of 652732.03 EUR
#
# ADAPTATION results for asset 317:
# Baseline damages for asset 317: 184843.07 to 184843.07 EUR
# Adapted damages for asset 317: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -184843.07 to -184843.07 EUR, (-100.0, -100.0)% change, at a cost of 1661576.62 EUR
#
# ADAPTATION results for asset 318:
# Baseline damages for asset 318: 2757758.77 to 4467438.01 EUR
# Adapted damages for asset 318: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -2757758.77 to -4467438.01 EUR, (-100.0, -100.0)% change, at a cost of 56790827.82 EUR
#
# ADAPTATION results for asset 319:
# Baseline damages for asset 319: 69456.26 to 169118.67 EUR
# Adapted damages for asset 319: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -69456.26 to -169118.67 EUR, (-100.0, -100.0)% change, at a cost of 1968840.21 EUR
#
# ADAPTATION results for asset 320:
# Baseline damages for asset 320: 119656.09 to 145995.72 EUR
# Adapted damages for asset 320: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -119656.09 to -145995.72 EUR, (-100.0, -100.0)% change, at a cost of 1483501.51 EUR
#
# ADAPTATION results for asset 321:
# Baseline damages for asset 321: 633711.63 to 2444420.76 EUR
# Adapted damages for asset 321: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -633711.63 to -2444420.76 EUR, (-100.0, -100.0)% change, at a cost of 14755046.36 EUR
#
# ADAPTATION results for asset 322:
# Baseline damages for asset 322: 18389.00 to 95262.00 EUR
# Adapted damages for asset 322: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -18389.00 to -95262.00 EUR, (-100.0, -100.0)% change, at a cost of 428160.80 EUR
#
# ADAPTATION results for asset 323:
# Baseline damages for asset 323: 147881.55 to 715931.44 EUR
# Adapted damages for asset 323: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -147881.55 to -715931.44 EUR, (-100.0, -100.0)% change, at a cost of 3443205.03 EUR
#
# ADAPTATION results for asset 359:
# Baseline damages for asset 359: 6718481.58 to 6718481.58 EUR
# Adapted damages for asset 359: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -6718481.58 to -6718481.58 EUR, (-100.0, -100.0)% change, at a cost of 60393241.32 EUR
#
# ADAPTATION results for asset 677:
# Baseline damages for asset 677: 466686.35 to 2417613.05 EUR
# Adapted damages for asset 677: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -466686.35 to -2417613.05 EUR, (-100.0, -100.0)% change, at a cost of 10866107.68 EUR
#
# ADAPTATION results for asset 692:
# Baseline damages for asset 692: 1256807.26 to 6510740.29 EUR
# Adapted damages for asset 692: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -1256807.26 to -6510740.29 EUR, (-100.0, -100.0)% change, at a cost of 29262914.93 EUR
#
# ADAPTATION results for asset 693:
# Baseline damages for asset 693: 475034.11 to 1251789.69 EUR
# Adapted damages for asset 693: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -475034.11 to -1251789.69 EUR, (-100.0, -100.0)% change, at a cost of 11060473.03 EUR
#
# ADAPTATION results for asset 943:
# Baseline damages for asset 943: 1708333.80 to 8799467.95 EUR
# Adapted damages for asset 943: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -1708333.80 to -8799467.95 EUR, (-100.0, -100.0)% change, at a cost of 79318549.39 EUR
#
# ADAPTATION results for asset 1122:
# Baseline damages for asset 1122: 731173.18 to 731173.18 EUR
# Adapted damages for asset 1122: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -731173.18 to -731173.18 EUR, (-100.0, -100.0)% change, at a cost of 6572603.94 EUR
#
# ADAPTATION results for asset 1123:
# Baseline damages for asset 1123: 1467351.38 to 7601439.01 EUR
# Adapted damages for asset 1123: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -1467351.38 to -7601439.01 EUR, (-100.0, -100.0)% change, at a cost of 34165126.09 EUR
#
# ADAPTATION results for asset 1124:
# Baseline damages for asset 1124: 1424691.89 to 7380446.61 EUR
# Adapted damages for asset 1124: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -1424691.89 to -7380446.61 EUR, (-100.0, -100.0)% change, at a cost of 33171862.41 EUR
#
# ADAPTATION results for asset 1125:
# Baseline damages for asset 1125: 2598459.64 to 2598459.64 EUR
# Adapted damages for asset 1125: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -2598459.64 to -2598459.64 EUR, (-100.0, -100.0)% change, at a cost of 23357867.11 EUR
#
# ADAPTATION results for asset 1126:
# Baseline damages for asset 1126: 544551.43 to 2284133.63 EUR
# Adapted damages for asset 1126: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -544551.43 to -2284133.63 EUR, (-100.0, -100.0)% change, at a cost of 20532352.77 EUR
#
# ADAPTATION results for asset 1127:
# Baseline damages for asset 1127: 423543.69 to 2134203.08 EUR
# Adapted damages for asset 1127: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -423543.69 to -2134203.08 EUR, (-100.0, -100.0)% change, at a cost of 9861593.93 EUR
#
# ADAPTATION results for asset 1128:
# Baseline damages for asset 1128: 557366.87 to 2887372.67 EUR
# Adapted damages for asset 1128: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -557366.87 to -2887372.67 EUR, (-100.0, -100.0)% change, at a cost of 12977470.60 EUR
#
# ADAPTATION results for asset 1129:
# Baseline damages for asset 1129: 120041.94 to 621862.95 EUR
# Adapted damages for asset 1129: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -120041.94 to -621862.95 EUR, (-100.0, -100.0)% change, at a cost of 2795000.55 EUR
#
# ADAPTATION results for asset 1130:
# Baseline damages for asset 1130: 278976.38 to 1426044.07 EUR
# Adapted damages for asset 1130: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -278976.38 to -1426044.07 EUR, (-100.0, -100.0)% change, at a cost of 6495556.19 EUR
#
# ADAPTATION results for asset 1131:
# Baseline damages for asset 1131: 17244.72 to 39207.33 EUR
# Adapted damages for asset 1131: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -17244.72 to -39207.33 EUR, (-100.0, -100.0)% change, at a cost of 401518.10 EUR
#
# ADAPTATION results for asset 1133:
# Baseline damages for asset 1133: 734767.76 to 3806376.82 EUR
# Adapted damages for asset 1133: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -734767.76 to -3806376.82 EUR, (-100.0, -100.0)% change, at a cost of 17107990.21 EUR
#
# ADAPTATION results for asset 1134:
# Baseline damages for asset 1134: 844988.95 to 4377364.56 EUR
# Adapted damages for asset 1134: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -844988.95 to -4377364.56 EUR, (-100.0, -100.0)% change, at a cost of 19674329.03 EUR
#
# ADAPTATION results for asset 1135:
# Baseline damages for asset 1135: 464550.17 to 2383350.63 EUR
# Adapted damages for asset 1135: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -464550.17 to -2383350.63 EUR, (-100.0, -100.0)% change, at a cost of 10941137.39 EUR
#
# ADAPTATION results for asset 1136:
# Baseline damages for asset 1136: 3231508.66 to 5532353.85 EUR
# Adapted damages for asset 1136: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -3231508.66 to -5532353.85 EUR, (-100.0, -100.0)% change, at a cost of 78816834.36 EUR
#
# ADAPTATION results for asset 1137:
# Baseline damages for asset 1137: 1434813.56 to 4720523.59 EUR
# Adapted damages for asset 1137: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -1434813.56 to -4720523.59 EUR, (-100.0, -100.0)% change, at a cost of 61456746.34 EUR
#
# ADAPTATION results for asset 1138:
# Baseline damages for asset 1138: 20042.30 to 103826.73 EUR
# Adapted damages for asset 1138: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -20042.30 to -103826.73 EUR, (-100.0, -100.0)% change, at a cost of 466655.48 EUR
#
# ADAPTATION results for asset 1139:
# Baseline damages for asset 1139: 615647.84 to 3189290.27 EUR
# Adapted damages for asset 1139: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -615647.84 to -3189290.27 EUR, (-100.0, -100.0)% change, at a cost of 14334457.45 EUR
#
# ADAPTATION results for asset 1140:
# Baseline damages for asset 1140: 128633.32 to 154984.17 EUR
# Adapted damages for asset 1140: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -128633.32 to -154984.17 EUR, (-100.0, -100.0)% change, at a cost of 1490775.56 EUR
#
# ADAPTATION results for asset 1141:
# Baseline damages for asset 1141: 7929.78 to 11152.58 EUR
# Adapted damages for asset 1141: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -7929.78 to -11152.58 EUR, (-100.0, -100.0)% change, at a cost of 184633.35 EUR
#
# ADAPTATION results for asset 1142:
# Baseline damages for asset 1142: 484071.97 to 2376837.18 EUR
# Adapted damages for asset 1142: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -484071.97 to -2376837.18 EUR, (-100.0, -100.0)% change, at a cost of 11270906.32 EUR
#
# ADAPTATION results for asset 1143:
# Baseline damages for asset 1143: 277589.27 to 1438018.12 EUR
# Adapted damages for asset 1143: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -277589.27 to -1438018.12 EUR, (-100.0, -100.0)% change, at a cost of 6463259.18 EUR
#
# ADAPTATION results for asset 1145:
# Baseline damages for asset 1145: 4709064.22 to 7596284.10 EUR
# Adapted damages for asset 1145: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -4709064.22 to -7596284.10 EUR, (-100.0, -100.0)% change, at a cost of 74378221.37 EUR
#
# ADAPTATION results for asset 1146:
# Baseline damages for asset 1146: 239373.88 to 1240047.84 EUR
# Adapted damages for asset 1146: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -239373.88 to -1240047.84 EUR, (-100.0, -100.0)% change, at a cost of 5573469.82 EUR
#
# ADAPTATION results for asset 1147:
# Baseline damages for asset 1147: 184343.02 to 184343.02 EUR
# Adapted damages for asset 1147: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -184343.02 to -184343.02 EUR, (-100.0, -100.0)% change, at a cost of 1657081.64 EUR
#
# ADAPTATION results for asset 1148:
# Baseline damages for asset 1148: 18772.40 to 97248.18 EUR
# Adapted damages for asset 1148: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -18772.40 to -97248.18 EUR, (-100.0, -100.0)% change, at a cost of 437087.80 EUR
#
# ADAPTATION results for asset 1150:
# Baseline damages for asset 1150: 2052.91 to 157088.68 EUR
# Adapted damages for asset 1150: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -2052.91 to -157088.68 EUR, (-100.0, -100.0)% change, at a cost of 1828789.84 EUR
#
# ADAPTATION results for asset 1989:
# Baseline damages for asset 1989: 4674658.11 to 7447213.20 EUR
# Adapted damages for asset 1989: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -4674658.11 to -7447213.20 EUR, (-100.0, -100.0)% change, at a cost of 74488849.83 EUR
#
# ADAPTATION results for asset 1990:
# Baseline damages for asset 1990: 88266.02 to 169104.62 EUR
# Adapted damages for asset 1990: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -88266.02 to -169104.62 EUR, (-100.0, -100.0)% change, at a cost of 1968676.63 EUR
#
# ADAPTATION results for asset 1991:
# Baseline damages for asset 1991: 26694.72 to 34328.82 EUR
# Adapted damages for asset 1991: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -26694.72 to -34328.82 EUR, (-100.0, -100.0)% change, at a cost of 399648.17 EUR
#
# ADAPTATION results for asset 1992:
# Baseline damages for asset 1992: 34237.34 to 95536.96 EUR
# Adapted damages for asset 1992: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -34237.34 to -95536.96 EUR, (-100.0, -100.0)% change, at a cost of 797166.30 EUR
#
# ADAPTATION results for asset 2193:
# Baseline damages for asset 2193: 1081803.77 to 5604155.55 EUR
# Adapted damages for asset 2193: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -1081803.77 to -5604155.55 EUR, (-100.0, -100.0)% change, at a cost of 25188215.11 EUR
#
# ADAPTATION results for asset 2194:
# Baseline damages for asset 2194: 1807992.49 to 9366089.69 EUR
# Adapted damages for asset 2194: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -1807992.49 to -9366089.69 EUR, (-100.0, -100.0)% change, at a cost of 42096455.01 EUR
#
# ADAPTATION results for asset 2195:
# Baseline damages for asset 2195: 106454.76 to 551476.20 EUR
# Adapted damages for asset 2195: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -106454.76 to -551476.20 EUR, (-100.0, -100.0)% change, at a cost of 2478643.04 EUR
#
# ADAPTATION results for asset 2196:
# Baseline damages for asset 2196: 150298.76 to 778604.81 EUR
# Adapted damages for asset 2196: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -150298.76 to -778604.81 EUR, (-100.0, -100.0)% change, at a cost of 3499486.28 EUR
#
# ADAPTATION results for asset 2197:
# Baseline damages for asset 2197: 448163.77 to 2321659.02 EUR
# Adapted damages for asset 2197: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -448163.77 to -2321659.02 EUR, (-100.0, -100.0)% change, at a cost of 10434836.51 EUR
#
# ADAPTATION results for asset 2198:
# Baseline damages for asset 2198: 301628.93 to 1562552.72 EUR
# Adapted damages for asset 2198: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -301628.93 to -1562552.72 EUR, (-100.0, -100.0)% change, at a cost of 7022987.44 EUR
#
# ADAPTATION results for asset 2231:
# Baseline damages for asset 2231: 5182.70 to 88997.57 EUR
# Adapted damages for asset 2231: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -5182.70 to -88997.57 EUR, (-100.0, -100.0)% change, at a cost of 1036089.01 EUR
#
# ADAPTATION results for asset 2232:
# Baseline damages for asset 2232: 0.00 to 48988.98 EUR
# Adapted damages for asset 2232: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): 0.00 to -48988.98 EUR, (0, -100.0)% change, at a cost of 285159.14 EUR
#
# ADAPTATION results for asset 2441:
# Baseline damages for asset 2441: 754584.75 to 1762121.42 EUR
# Adapted damages for asset 2441: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -754584.75 to -1762121.42 EUR, (-100.0, -100.0)% change, at a cost of 18646412.04 EUR
#
# ADAPTATION results for asset 2444:
# Baseline damages for asset 2444: 1531458.06 to 2813742.85 EUR
# Adapted damages for asset 2444: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -1531458.06 to -2813742.85 EUR, (-100.0, -100.0)% change, at a cost of 25293073.89 EUR
#
# ADAPTATION results for asset 2445:
# Baseline damages for asset 2445: 4108449.48 to 4108449.48 EUR
# Adapted damages for asset 2445: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -4108449.48 to -4108449.48 EUR, (-100.0, -100.0)% change, at a cost of 36931347.98 EUR
#
# ADAPTATION results for asset 2560:
# Baseline damages for asset 2560: 229398.67 to 1188372.50 EUR
# Adapted damages for asset 2560: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -229398.67 to -1188372.50 EUR, (-100.0, -100.0)% change, at a cost of 5341211.89 EUR
#
# ADAPTATION results for asset 2561:
# Baseline damages for asset 2561: 300350.48 to 1131238.38 EUR
# Adapted damages for asset 2561: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -300350.48 to -1131238.38 EUR, (-100.0, -100.0)% change, at a cost of 8499727.40 EUR
#
# ADAPTATION results for asset 2562:
# Baseline damages for asset 2562: 275969.83 to 1429628.83 EUR
# Adapted damages for asset 2562: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -275969.83 to -1429628.83 EUR, (-100.0, -100.0)% change, at a cost of 6425553.01 EUR
#
# ADAPTATION results for asset 2563:
# Baseline damages for asset 2563: 102331.82 to 530117.80 EUR
# Adapted damages for asset 2563: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -102331.82 to -530117.80 EUR, (-100.0, -100.0)% change, at a cost of 2382646.42 EUR
#
# ADAPTATION results for asset 2564:
# Baseline damages for asset 2564: 155885.03 to 807543.84 EUR
# Adapted damages for asset 2564: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -155885.03 to -807543.84 EUR, (-100.0, -100.0)% change, at a cost of 3629554.51 EUR
#
# ADAPTATION results for asset 2565:
# Baseline damages for asset 2565: 77664.69 to 402332.67 EUR
# Adapted damages for asset 2565: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -77664.69 to -402332.67 EUR, (-100.0, -100.0)% change, at a cost of 1808308.45 EUR
#
# ADAPTATION results for asset 2580:
# Baseline damages for asset 2580: 644656.55 to 1577676.30 EUR
# Adapted damages for asset 2580: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -644656.55 to -1577676.30 EUR, (-100.0, -100.0)% change, at a cost of 17472971.63 EUR
#
# ADAPTATION results for asset 2725:
# Baseline damages for asset 2725: 16512.95 to 85543.38 EUR
# Adapted damages for asset 2725: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -16512.95 to -85543.38 EUR, (-100.0, -100.0)% change, at a cost of 384479.88 EUR
#
# ADAPTATION results for asset 2726:
# Baseline damages for asset 2726: 282586.91 to 1367119.70 EUR
# Adapted damages for asset 2726: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -282586.91 to -1367119.70 EUR, (-100.0, -100.0)% change, at a cost of 6579621.94 EUR
#
# ADAPTATION results for asset 3004:
# Baseline damages for asset 3004: 355376.38 to 355376.38 EUR
# Adapted damages for asset 3004: 0.00 to 0.00 EUR
# Change (Adapted-Baseline): -355376.38 to -355376.38 EUR, (-100.0, -100.0)% change, at a cost of 3194521.13 EUR

# %%
# indirect damages adaptation
fully_protected_assets=[asset_id for asset_id, damages in adaptation_run[1].items() if damages[0]==0 and damages[1]==0]
basin_list=[2080411370]

#load pickled shortest paths, disrupted edges, shortest paths, graph
shortest_paths = pickle.load(open(data_path / 'interim' / 'indirect_damages' / 'shortest_paths.pkl', 'rb'))
disrupted_edges = pickle.load(open(data_path / 'interim' / 'indirect_damages' / 'disrupted_edges.pkl', 'rb'))
G = pickle.load(open(data_path / 'interim' / 'indirect_damages' / 'G.pkl', 'rb'))
disrupted_shortest_paths = pickle.load(open(data_path / 'interim' / 'indirect_damages' / 'disrupted_shortest_paths.pkl', 'rb'))

# %%
def recalculate_disrupted_edges(G, assets, disrupted_edges, fully_protected_assets):
    # list of osm_ids of adapted assets
    adapted_osm_ids=assets.loc[assets.index.isin(fully_protected_assets)]['osm_id'].values
    protected_edges=[]
    for (u,v) in disrupted_edges:
        # get the attributes of the edge
        osm_ids_edge = G.edges[(u,v,0)]['osm_id'].split(';')
        print('osm_ids_edge: ', osm_ids_edge)
        print('adapted_osm_ids: ', adapted_osm_ids)
        # check if all the osm_ids of the edge are in the list of adapted assets
        if set(osm_ids_edge).issubset(adapted_osm_ids):
            protected_edges.append((u,v))
            print('edge protected: ', u, v)
    return [edge for edge in disrupted_edges if edge not in protected_edges]

adapted_disrupted_edges = recalculate_disrupted_edges(G, assets, disrupted_edges, fully_protected_assets)



# for basin in basin_list:
#     # find edges that will no longer be disrupted

#     disrupted_shortest_paths[basin] = shortest_paths[basin]
    
#     # open pickled graph
#     # rerun the indirect damages calculation excluding the adapted assets
#     # calculate the difference in indirect damages
# Out:
# osm_ids_edge:  ['27938387']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['27938387']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['232695358', ' 114108477', ' 456059767']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['114105223']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['114105223']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['114105226']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['114105226']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['114105227']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['114105227']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['114108480']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['114108480']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['227826738', ' 661223367', ' 227826738']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['232695358', ' 114108477', ' 456059767']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']
# osm_ids_edge:  ['227826738', ' 661223367', ' 227826738']
# adapted_osm_ids:  ['7990468' '33506715' '33849041' '33849042' '33884053' '33884055'
#  '34009391' '34010873' '34010874' '35031438' '103679880' '109834742'
#  '109834743' '110875739' '111545087' '111545089' '111545090' '111545091'
#  '111545092' '111578962' '111578964' '111578967' '111578969' '111578971'
#  '111578975' '111578977' '111578979' '111578983' '111578985' '111578987'
#  '111578988' '111578991' '111578992' '111578995' '111578997' '111579000'
#  '111579004' '111579006' '111579008' '111579013' '239167713' '239167714'
#  '239167715' '239167716' '264340478' '264340482' '264340485' '264340488'
#  '264340490' '264340491' '306183322' '306183324' '445534449' '445534452'
#  '445534453' '481469565' '481469566' '481469567' '481469568' '481469569'
#  '481469570' '484214697' '601081464' '601081465' '876311581']

# %%
#assets.loc[(fully_protected_assets)]
#str(filtered_assets['osm_id'].values)
# adapted_disrupted_edges
# disrupted_edges
G.edges[(248, 249,0)]
# Out:
# {'osm_id': '27938387',
#  'asset': 'rail',
#  'name': 'Rechte Rheinstrecke',
#  'gauge': '1435',
#  'electrified': 'contact_line',
#  'voltage': '15000',
#  'bridge': 'None',
#  'maxspeed': '110',
#  'service': '',
#  'tunnel': 'None',
#  'other_tags': '"frequency"=>"16.7","operator"=>"DB Netz AG","passenger_lines"=>"2","railway:lzb"=>"no","railway:pzb"=>"yes","railway:traffic_mode"=>"mixed","ref"=>"2324","usage"=>"main"',
#  '_11': '"mixed"',
#  'usage': '"main"',
#  'geometry': <LINESTRING (8.3e+05 6.52e+06, 8.3e+05 6.52e+06, 8.29e+05 6.52e+06)>,
#  'buffered': '',
#  'id': 1403,
#  'from_id': 248,
#  'to_id': 249,
#  'length': 1087.0006162750026,
#  'weight': 1087001,
#  'capacity': 1}

# %%
# EXPAND FOR VISUALISATION SCRIPT
# Create visualisation for the basin and the discharge points
from lonboard import Map, PolygonLayer, PathLayer, BaseLayer
import ast
# MIRACA color scheme
color_string = config.get('DEFAULT', 'miraca_colors')
miraca_colors = ast.literal_eval(color_string)

basin_id = 2080411370

    
# Set path for basin to add to visualization
basin_path = rf'C:\Data\Floods\basins\hybas_eu_{int(basin_id)}.shp'

# Generate the basin layer
basin = gpd.read_file(basin_path)
layer_basin = PolygonLayer.from_geopandas(basin,
    get_fill_color=miraca_colors['grey_200'],
    get_line_color=miraca_colors['primary blue'], get_line_width=70,
    auto_highlight=False,
    filled=True, opacity=0.2)

# Set path for the protected area to add to visualization
adapt_path = rf'C:\Data\interim\adaptations\test_haz_level_adapt.geojson'
adapt_area = gpd.read_file(adapt_path)
layer_protected_area = PolygonLayer.from_geopandas(adapt_area,
    get_fill_color=miraca_colors['green_success'],
    get_line_color=miraca_colors['green_400'], get_line_width=30,
    auto_highlight=False,
    filled=True, 
    opacity=0.2)

# Create layer for assets for visualization
layer_assets = PathLayer.from_geopandas(assets.drop(columns=['buffered']), get_width=2, get_color=miraca_colors['black'], auto_highlight=True, )
affected_assets = [asset_id for asset_id in list(set(overlay_assets.asset.values))]
layer_affected_assets = PathLayer.from_geopandas(assets.iloc[affected_assets].drop(columns=['buffered']), get_width=3, get_color=miraca_colors['red_danger'], auto_highlight=True)
layer_protected_assets = PathLayer.from_geopandas(f_assets.drop(columns=['buffered']), get_width=4, get_color=miraca_colors['green_success'], auto_highlight=True)
layers_assets = [layer_assets, layer_affected_assets, layer_protected_assets]
# Flood return period: H for frequent(RP10-20), M for 100 year return period (RP100) and L for extreme (RP2000)
return_period_str='L'
# Generate flood layers and protection layers for visualization
flood_plot_path=rf'Floods\Germany\basin_intersections\DERP_RW_{return_period_str}_4326_hybas_intersections\flood_DERP_RW_{return_period_str}_4326_{basin_id}.geojson'
flood_m = data_path / flood_plot_path
flood_gdf=gpd.read_file(flood_m)
layers_flood=[]
f_area_colors = {1:'blue', 3:'green'}
for f_area in flood_gdf.flood_area.unique():
    for f_depth in flood_gdf.depth_class.unique():
        subset_gdf = flood_gdf[(flood_gdf.depth_class==f_depth) & (flood_gdf.flood_area==f_area)]
        if not subset_gdf.empty:
            color_key=f'{f_area_colors[f_area]}_{f_depth}00'
            layers_flood.append(PolygonLayer.from_geopandas(subset_gdf, 
                                                            get_fill_color=miraca_colors[color_key], 
                                                            opacity=0.5, 
                                                            stroked=False))


layers=[]
if layer_basin is not None:
    layers.append(layer_basin)
else:
    print('No basin layer')

if layer_protected_area is not None:
    layers.append(layer_protected_area)
else:
    print('No protected area layer')

if layers_flood is not None:
    layers.extend(layers_flood)
else:
    print('No flood layers')

if layer_assets is not None:
    layers.extend(layers_assets)
else:
    print('No asset layer')
Voyager = 'https://basemaps.cartocdn.com/gl/voyager-gl-style/style.json'


# m=Map(layer_affected_assets, show_tooltip=True, basemap_style=Voyager)
m = Map(layers, show_tooltip=True, basemap_style=Voyager)
# Out:
# c:\Users\peregrin\AppData\Local\anaconda3\envs\ci_adapt_env\Lib\site-packages\lonboard\_geoarrow\ops\reproject.py:97: UserWarning: Input being reprojected to EPSG:4326 CRS
#   warnings.warn("Input being reprojected to EPSG:4326 CRS")
# c:\Users\peregrin\AppData\Local\anaconda3\envs\ci_adapt_env\Lib\site-packages\lonboard\_geoarrow\ops\reproject.py:97: UserWarning: Input being reprojected to EPSG:4326 CRS
#   warnings.warn("Input being reprojected to EPSG:4326 CRS")
# c:\Users\peregrin\AppData\Local\anaconda3\envs\ci_adapt_env\Lib\site-packages\lonboard\_geoarrow\ops\reproject.py:97: UserWarning: Input being reprojected to EPSG:4326 CRS
#   warnings.warn("Input being reprojected to EPSG:4326 CRS")
# Map(basemap_style='https://basemaps.cartocdn.com/gl/voyager-gl-style/style.json', layers=[PolygonLayer(filled=…

# %%
m
# Out:
# Map(basemap_style='https://basemaps.cartocdn.com/gl/voyager-gl-style/style.json', layers=[PolygonLayer(filled=…
